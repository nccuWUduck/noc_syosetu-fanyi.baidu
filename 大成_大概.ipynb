# %%
# -- coding: UTF-8 –-
import requests as rq
from bs4 import BeautifulSoup
import io
import time
import urllib.request
import csv
def sleeptime(hour,min,sec):
    return hour*3600 + min*60 + sec;
# -- coding: UTF-8 –-
import os
import json
import zipfile
from selenium import webdriver
import re
import requests as rq
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
link_want = input('請輸入你的網址：')
# Out:
# 請輸入你的網址：https://novel18.syosetu.com/n0253hw/

# %%
#org_name = '牛娘の乳搾り'
org_name=input('請輸入你的檔案名：')
# Out:
# 請輸入你的檔案名：撮った娘をお下品痴女ビッチ

# %%
#link_want = "https://novel18.syosetu.com/n5270fu/"

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:60.0) Gecko/20100101 Firefox/60.0'}
nl_response = rq.get(link_want,headers=headers,cookies={'over18':'yes'})
soup = BeautifulSoup(nl_response.text, 'html.parser')
doc_list=[]
for link in soup.find_all('dd'):
    #print(link.find('a').get('href'))
    response=link.find('a').get('href')
    doc_list.append(response)

# %%
japan_list=[]
for link in soup.find_all('dd'):
    tmp=[]
    print(link.find('a').get('href'))
    response = rq.get("https://novel18.syosetu.com/"+link.find('a').get('href'),headers=headers,cookies={'over18':'yes'})    
    html_doc = response.text # text 屬性就是 html 檔案
    soup = BeautifulSoup(response.text, "lxml")
    tmp=soup.find('div',class_="novel_view",id="novel_honbun").text
    tmp=''.join(tmp)
    japan_list.append(tmp)
# Out:
# /n0253hw/1/
# C:\Users\user\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# /n0253hw/2/
# /n0253hw/3/
# /n0253hw/4/
# /n0253hw/5/
# /n0253hw/6/
# /n0253hw/7/
# /n0253hw/8/
# /n0253hw/9/
# /n0253hw/10/
# /n0253hw/11/
# /n0253hw/12/
# /n0253hw/13/
# /n0253hw/14/
# /n0253hw/15/

# %%
#兩種，，，5000字還是spilt之後merge

# %%
japan_list_spilt = []
for str1 in japan_list:
    tmp = str1.split()
    japan_list_spilt.append(tmp)
japan_list_spilt_merge = []
for i in japan_list_spilt:
    count = 0
    japan_tmp_5 = []
    japan_list_spilt_merge_tmp = []
    for j in i:
        
        count += 1
        japan_tmp_5.append(j)
        if(count == 40):
            japan_list_spilt_merge_tmp.append('\n'.join(japan_tmp_5))
            count = 0
            japan_tmp_5 = []
    if(len(japan_tmp_5)!=0):
        japan_list_spilt_merge_tmp.append('\n'.join(japan_tmp_5))
        japan_tmp_5=[]
        count = 0
    japan_list_spilt_merge.append(japan_list_spilt_merge_tmp)

# %%
len(japan_list_spilt_merge)
# Out:
# 15

# %%
japan_list_spilt_merge[11]
# Out:
# ['「おかーさーん、ほらほら！\nすごい、すごーい」\n小学生に入った頃だろうか髪をツインテールに結んだ女の子が公園のブランコを漕いで楽しんでいる。明るめのスカートとプリントシャツが子供らしさと全面に出している。母親も側で見ているが女児が思いっきりブランコを漕いでもそこまで振れないのでバランスを崩さないか見守ってるぐらいだろう。\nなかなかに、ほほえましい風景だ。\n「アオイちゃん。きちんと手は握っておいてね」\n「はーい」\n買い物の帰りなのか食材がぱんぱんに入ったビニールをベンチに置いてやや心配そうに娘さんを見ている奥さん。身長は高めで長い髪をまとめて地味目のブラウスとチェックのスカートを着ている、ザ・奥さんと言った感じ、体つきは一児？\nを生んだと思えないほどのボッキュボンでなかなかの逸材だ。\n「おや、買い物の帰りですか？」\n「え、ええ？……あら、お隣さんでしたか、こんにちは。今日は祝日なので娘と買い物にでかけてたんですよ」\n先程、気づかれないぐらいの距離で変態カメラで母娘を撮って、親しいお隣さんと書き込んでおいたので問題なく話しかけれたようだ。\n「お野菜が痛むからそろそろ帰るわよー」\n「えー」\n「おやつの時間はもうすぐだけどいいのかな？』\n「帰るー！」\n微笑ましい母娘のやり取りである。うん、今日はこの母娘をいただくことにしようかな。\nそう考えながらニコニコと母娘のやり取りを眺めちょうどいいタイミングで声をかける。\n「あ、重そうですし。持ちましょうか。どうせお隣ですし」\n「まあ、悪いですわ。毎日のことですから」\nやんわりと断られるが特に悪感情はなさそう。ここでもうひと押し。\n「ダイエットも兼ねて散歩にでかけてるだけで、ほらカメラしか持ってませんからちょうどいい運動にもなりそうだし」\n「おじさんの持ってるのカメラなの？」\nおや、ツインテロリっ子ちゃんが釣れたようだ。なら、パシャっと。\n「そうだよ。はいちーず！」\n「きゃっ！」\nびっくりする奥さんとずいっと前に出て面白そうにポラロイドカメラを観察するツインテロリっ子ちゃん。\nおもったよりも自由奔放な性格のようだ。出てきた写真が現像される様を面白そうに見てる。\n「すごいすごい！\nスマホと違って紙の写真！\n始めてみた！！」\nいきなり写真を撮るのは無作法だったけど、娘さんが喜んでいるのでまあいっかとため息を付いて見守る奥さん。くっくく、今回はじっくりと楽しませてもらう方向で行くことにするか。\n「はいはい、お母さんも困ってるから家に帰ろうね。なんなら、帰ってから何枚か撮ってあげるから」\nさっと、買い物の荷物をこちらで持って公園の出口にツインテロリっ子ちゃんを押し出すように進める。\n「ほんと！\n約束だよ！\nパシャって可愛く撮ってね！」\n「もう、まあお隣さんだから大丈夫でしょう。じゃあ、帰ろうね」\nと、三人で公園を出るのだった。\n「それじゃあ、旦那さんは長期出張で海外に？」\n「ええ、まあ、始めてのことじゃないですし。幸い、専業主婦なので」',
#  '他愛も無い話題で家庭情報を聞き出しつつ住宅街を歩いて行く。ツインテロリっ子ちゃんはカメラでだいぶ懐いてくれたのか、ブンブンと繋いだ手をふりまくってごきげんだ。\n「荷物を持って娘の相手をしてくれたお礼もしたいのでよっていってくださいね」\nそう言われて、そんな気を使ってもらわないでもとにっこりと笑いながら母娘のお宅にお邪魔することに成功。二階建ての一軒家で掃除もきれいにされていて理想的なお宅だね。\nダイニングで麦茶をごちそうになる。なお、ツインテロリっ子ちゃんはおやつのカステラと格闘中だ。すでに母娘は変態カメラで撮られることに違和感は覚えないぐらい影響は受けているので遠慮なく写真を撮っていく。家事の途中の奥さんには『家の中では性的なことをするのは当たり前』、ツインテロリっ子ちゃんには『楽しいと発情していく』などなど、どスケベワードを書き込んでいく。\n「おかーさーん！\nおじさんに可愛いの撮ってもらった！！」\n「あらあら、ありがとうございます。やっぱり、父親がいないと寂しいのかこの子、今日はとっても元気で」\n「ははは、これぐらい構いませんよ。独り身なのでこちらとしても久しぶりのアットホームな雰囲気を楽しませてもらってますから」\nにこにこと人のいいおじさんを演じて下準備を進める。\n「そうだアオイちゃん、学校の宿題は？」\n「えっ……えっとぉ」\n「奥さんは忙しそうですし、私が見ておきましょうか？」\n急に元気の無くなったツインテロリっ子ちゃんに助け舟を出す素振りで話しかける。ツインテロリっ子ちゃんと奥さんの表情から問題なさそうだな。\n「やった！\nありがとうおじさん！」\n「もう、しかたないわね。お行儀よく見てもらうのよ」\nそんなこんなでツインテロリっ子ちゃんのお部屋に入ることに成功する。おもったよりもきちんとした部屋だ。奥さんの教育がいいのだろう。ベッドに勉強机にタンス。おもちゃ箱あるな。\n「えっとー、宿題は……算数と国語と理科！」\nランドセルから元気に教科書を取り出すが、鉛筆の進みはだいぶ遅い感じだ。\n「それじゃあ、おじさんが宿題が進むおまじないで写真を撮ってあげるね」\n「ええー！\n写真で宿題ができちゃうの！？」\n「おまじないだからね。きちんと自分でやるのは必要だよ」\n「はーい」\nなかなかいい子だ。パシャっと算数の宿題で掛け算を書いている様子を撮って、『理解度上昇』と書いて上げる。\n「わわわ、ほんとに宿題が簡単になってる！？」\nうんうん、それじゃあもっとおまじないで撮ってあげよう。もう一度『書くのが楽しくなる』とツインテロリっ子ちゃんの写真に、国語の教科書が写ったところに『淫語のお勉強』、理科の教科書には『大人の保険体育』と。\n「もう算数できちゃった。ありがとうおじさん！\nそれじゃあ、次もなんだか書いていくのが楽しくいの」\nいい笑顔で変態カメラで変換した国語の教科書を開く。心なしか頬が赤いのは楽しくて発情しちゃってるのもあるのかな。\n「えっと、いんらんはこうやって書いて。へんたい、変態と……おじさんのおまじないすごい！\nこんな難しい漢字もかけちゃうなんて！」\n無邪気に淫語を口に出してノートに書いていく女の子、いいねいいね。おじさんもおちんちんむくむくっとしてきたよ。あ、もちろん、ロリも熟女も美味しく食べれます。\n楽しく宿題をしていくツインテロリっ子ちゃんだが、だんだん言葉が少なく、息が荒くなっていく。完全に発情してるけど自分がどういう状況なのかわかってない様子だね。変態カメラの効果がきちんと出てるようだ。']

# %%
#japan_list_spilt_merge[65]

# %%
#japan_list_spilt_merge=japan_list_spilt_merge[101:]

# %%
len(japan_list_spilt_merge)
# Out:
# 15

# %%
japan_list_spilt_merge[0]
# Out:
# ['オークションサイトで変なカメラを買った。見た目は古めのインスタントカメラ。\n商品のタイトルは変態カメラ。撮った女をお下品、痴女、ビッチお好きに変えちゃう夢のカメラ。だそうだ。\n「宝くじが当たって数年遊べる金が入ったテンションでネットサーフィンしたのがいけなかった」\nお金が入ってまっさきに買ったのが怪しいエロアイテム。今日通販サイトから届いてダンボールの箱を明けた時点でちょっと素に戻ってたそがれてしまった。\n明らかに冗談なのだけど、見つけた時はテンションあがったんだけど……目の前には片手に収まるぐらいの安っぽくもなく高級そうでもない普通のザ・カメラと言った感じのカメラがある。\n「まあ、そこそこの値段なので１回だけでも使うか」\nふむ、ちょうど下校時間が近い。たしかアパートから十数分ほど離れたところの商店街と住宅街の境目でいい感じに女子高生とかとすれ違うポイントがあったな。\n「いやいや、これではまるで盗撮狙いの変質者の思考じゃないか……まあ、これから近いことしちゃうんだけど。お金はあるから１回ぐらいならセーフだろうか。ええっい、当たって砕けろだ！」\nというわけで、散歩に出かける風な当たり障りのない服装で街に出てみた。片手にはポラロイドカメラ。この時点で怪しい感じだと思うのは被害妄想だろうか。\nやや後ろめたい感情と、ちょっといけないことをしてるようなワクワク感でテンションが上がってきちゃったぞ。お、そして人気のない路地で一人で歩いている制服の女の子発見。\n「あ、ちょっと写真とっても良い？」\n「ひゃぃ！？」\n流石に、いきなり写真を撮るのはまずいかと思い、声をかけてみる。うむ。OKをもらえたようだ。たぶん。\n「OKもらえた。では、はいちーず」\n後ろから声をかけられてビクッと振り向いた女の子をカメラのフレームに納める。翻った膝下まであるスカート、凹凸感は少ないけど華奢な体に清潔感のあるセーラー服、長い髪の大人しそうだがそこそこ可愛い顔、いいね。はい、パシャっと。\n「え、え！？」\nストロボが一瞬光って、ジジジっと感光紙独特の光沢がある写真が出てくる。おもったより早いけど、まだ写真は真っ白だ。\n制服の女の子は驚きで固まったまま。警察を呼ぶとかまでいかなくて済んだようだ、これなら謝り倒したら許してくれるかな？……ん、現像がはじまったか、真っ白だった表面にじんわりと女子生徒の姿が現れて……\n写真には制服の女の子が写っていた。当然だ、だけど、違和感がある。たしか、写真を取る前にフレームで見た制服のスカートは膝下で胸もBまでない感じだったはず。それが、写真の中の姿は、太ももぐらいまでしかないミニスカで制服の上からもわかるぐらいのおっぱい。Dはあるだろうか。\n「おお、本物！？」\n周囲も気にせずに声を上げて目の前の女子生徒を見ると、たしかに写真と同じミニスカで雰囲気もややエロっぽくなってる。\n女子生徒は写真を取られたことにびっくりしているだけで、制服や体が変わったことには気づいて無い様子。\n「急にごめんごめん、ちょっと欲しかったインスタントカメラ手に入れたからどうしても試しどりしたくて、おじさん、かわいいこなんて知り合いに居ないからついキミに声をかけちゃって、写真撮りたいだけだから、撮った写真は全部渡すから、ほんと、おねがい、もうちょっと写真取らせて。ね、ね、おねがいします」\nはい、土下座して頼んでみました。\n推しに弱そうなのでいけるか？\nローアングルからのミニスカだと中身がチラ見えでとてもいい光景……いやいや、そこではなく女子高生ちゃんの表情は困惑してるけど、もうちょっとでいける。\n「ま、まあ……ちょっとぐらいなら……」\n迫真の土下座３回目で行けた。人間やればできるものだ。\nまあ、あまりの嬉しさにバネのようにビョンって土下座から直立したらちょっと距離を取られちゃった。ぐすん。\n「さて、気を取り直してカメラを構える。変態カメラの効果はさっき撮った通り本物だ。それなら、おっぱい……ごほん、お胸をアップ出とったらどうなるだろう」\nパシャっと胸をアップで撮る。女子高生ちゃんのDカップのちょっと存在感のあるおっぱいが１周りでかく、いや２周りぐらいでっかく写った写真が出てきた。これはもう巨乳と言ってもいいレベル。\n「？？？」\n女子生徒ちゃんはなにか違和感はあるけど、自分の体の変化にはやっぱり気づいていない様子だ。実査にはお胸がセーラー服を盛り上げておへそが見えちゃってる。ああ、セーラー服も丈が短くなってるのか。すごいぞ変態カメラ。\n人通りがないとは言え、ここも通学路なのであんまり時間はかけていられない。パシャパシャパシャと色んな角度で撮っていく。\n「おお！\nいいよ。いいよ」\n全体写真を取ると制服の丈が短くなって、バストアップを撮ると胸が大きく、ローアングルで撮るとお尻や太ももはむっちりとなって、下着も白のショーツから赤いレースに、中身にも影響しているのか表情も地味で真面目そうな雰囲気がどんどん崩れてほほに赤みがかかって、もしかしてエッチな気分になってるのかな？\n（うぉっ！？\n思ったよりもドスケベな姿に……もっと撮ったらもしかしてヤらしてくれる雰囲気まで行くか？\nしかし、そろそろ人通りが多くなる時間帯、ここまでにするにはもったいないけど、どうしよう）',
#  'とりあえず、今まで取った写真を渡すことにした。効果はわかったので焦る必要もなさそうだし。\n「はい、じゃあ約束の写真。ありがとね」\n「あ、は、はい……」\n受け取った写真をまじまじと見つめる女子高生ちゃん。真っ赤になってるけど、嫌悪感は全くない感じでまんざらでもなさそうだ。\nもうひと押しで落とせそうだな。食わぬ据え膳は武士の恥ともいうし、やっぱチャンスがあるなら最後までごちになりたい。ここでおあずけはないね。\n「えっと、もうちょっと写真とっても良い？」\n「……はい」\n（これは、行ける。上目遣いでこっち見ちゃって、絶対もっと取ってもらいたいって思ってる！\nおじさんがんばっちゃうよ！！）\n先よりも近くでねちっこく撮ってみるが、女子高生はきちんと目線を送ってくれて撮れば撮るほどエッチな雰囲気になってきたぞ。\nさっきまでも十分どスケベだったけど。今の女子高生ちゃんは、下半身ムッチリの肉付きに、スカートはもうパンツが隠れないぐらいに短く、上半身はさらに際どく胸はGとかHとかの巨乳に育ったため服の上からは乳輪と乳輪もはっきりと形がわかるようになっている。ブラもなくなって制服の丈なんて４０ｃｍあるかないかでおっぱいの下がはっきりと覗いていて、とても眼福です。\nここまで来てるのに本人は自分の格好に違和感はほぼない模様。神かよ変態カメラ。\n（これは、踏み込んでも良いかも）\n追加で撮った写真も女子生徒ちゃんに渡してあげると写真に穴が空くぐらいじっくりと見ている。離れていてもわかるぐらい荒い息で「うゎ」と「かあ、あ」、とか下品な角度で撮られた自分の体で興奮しているのはまるわかりだ。\n「うんうん、すごい綺麗だよ。綺麗でエロい。ほら、おじさんのここもとっても元気になってる」\n女子生徒ちゃんに見せつけるようにパッツンパッツンにテントを張っている自分の股間を目の前に持ってくる。\n「ありがとうございます！\n……え、ええ！？」\n（催眠術？\n洗脳？\n変態カメラでとったことで頭の中もエッチでどスケベな方向に変化しちゃってるぽいな。これはいいぞ）\n最初は驚いていた女子生徒ちゃんだが、すぐにとろんとした目でズボンの膨らみを見つめている。ちなみに、おっさんには罪悪感はほぼない。女子生徒ちゃんも喜んでるし、自分も楽しめる。ウィンウィンというやつ、これくらいで罪悪感を覚えるようならあんなゲスな売り文句の通販など買わないのだ。']

# %%
driver = webdriver.Chrome(r"C:\Users\user\Desktop\JYPUTER_試做\翻譯_總整理\chromedriver")
driver.get("https://fanyi.baidu.com/#jp/zh/") # 更改網址以前往不同網頁
driver.implicitly_wait(5)
# <textarea class="textarea" id="baidu_translate_input" data-height="70" style="height: 70px; overflow: hidden;"></textarea>
#driver.close()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6668\1940109115.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\user\Desktop\JYPUTER_試做\翻譯_總整理\chromedriver")

# %%
try:                      # 使用 try，測試內容是否正確
    elements = driver.find_elements(By.CLASS_NAME, "app-guide-close")[0]
    elements.click()
except:                   # 如果 try 的內容發生錯誤，就執行 except 裡的內容
     print('wait')

# %%
# soup_try = BeautifulSoup(driver.page_source, 'lxml')
# kkk = soup_try.find_all(id="original-output")

# %%
# kkk

# %%
# elements = driver.find_elements(By.ID, "translate-button")[0]
# elements.click()

# %%
from selenium.webdriver.common.keys import Keys
中文翻譯_list = []
n = 0
for i in japan_list_spilt_merge:
    print(n)
    中文翻譯_list_tmp = []
    for j in i:
        flag=1
        if (j==''):
            flag=0
            continue
        #     if(n==10):
        #         break
        #舊版程式是用  find_element_id 之類的寫法
        search_input = driver.find_element('id', 'baidu_translate_input')
        search_input.send_keys(j)
        
#         elements = driver.find_elements(By.ID, "translate-button")[0]
#         elements.click()
        time.sleep(10)
          
        soup_try = BeautifulSoup(driver.page_source, 'lxml')
        kkk = soup_try.find_all(id="original-output")
#         if(kkk==kkk_pre):
            
        
#        trans-btn trans-btn-zh
        for kk in kkk:
            # print(i.string)
            # 中文翻譯_list_tmp.append(kk.string)
             中文翻譯_list_tmp.append(kk)
        
        search_input = driver.find_element('id', 'baidu_translate_input')
        search_input.send_keys(Keys.CONTROL + "a")
        search_input.send_keys(Keys.DELETE)
        
        n += 1
    if (flag==1):
        中文翻譯_list.append(中文翻譯_list_tmp)
        print("start")
    

search_input = driver.find_element('id', 'baidu_translate_input')
search_input.send_keys(Keys.CONTROL + "a")
search_input.send_keys(Keys.DELETE)
# Out:
# 0
# start
# 2
# start
# 5
# start
# 7
# start
# 9
# start
# 11
# start
# 14
# start
# 16
# start
# 20
# start
# 21
# start
# 23
# start
# 26
# start
# 28
# start
# 31
# start
# 34
# start

# %%
len(中文翻譯_list)
# Out:
# 15

# %%
中文翻譯_list[6]
# Out:
# [<div id="original-output" style="display:none;"><p>“啊，是大叔！”</p><p>「咦，诶……是谁？」</p><p>在某个地方听到了这样的声音，回头一看，站着一个似曾相识的辣妹和一个不认识的校服姑娘。啊，这里是第一次使用变态相机时的小巷吗。</p><p>几次H的女生改，bitch辣妹。习惯了相机之后转了很多圈，感觉真的好久不见了。旁边的是学校的朋友吗。普通的制服膝下的裙子，头发是黑发很好的半长，不过，是有意地伸长刘海的朴素可爱的眼罩。虽然和现在的小辣妹组合很不协调，但是和第一次见面时的气氛很搭呢。</p><p>“没关系吗？</p><p>在学校也不要跟着不认识的人……“</p><p>“没关系，没关系！”</p><p>和叔叔玩了好几次的通货紧缩，是朋友哦。喂……啊，拍照太好了。“</p><p>“你是朋友吗？”</p><p>“那个，虽然和小萌的班级不一样，但是到去年为止都是在文艺部一起的。啊，因为只有3个部员，所以年末就废部了。”</p><p>和和气地说话的大叔和同学不知道该怎么办才好，慌慌张张的眼睛藏着。</p><p>看来，废部之后就疏远了，好久没在校门前见面了，所以一起回去了。大概，废部后用变态照相机拍了很多，所以眼窝好像很困惑。但是，我会好好听你的话，很好。嗯嗯，这里叔叔帮你脱一身吧。</p><p>“对了，要给你拍几张纪念照吗？”</p><p>把变态相机对准两个人。眼窝可能是在警戒第一次见面的大叔，但是比奇辣妹会笑着在相机上摆出姿势，给我做双拍子。另外，为了不让眼窝逃跑而压抑着。</p><p>“看，奶酪，奶酪！”</p><p>“啊，嗯！？”</p><p>啪嚓一声。嗯，拍到了感觉很好的好朋友的纪念照片。</p><p>拍女生的时候也是这样的反应啊，一边怀念一边拍着两个人。</p><p>“啊！？”“视线，视线♪”“那么，哇……”“嗯，这是什么……？”“哇，哇，啊♡”“好厉害吧♡”</p><p>叔叔的相机技巧♡“</p><p>随着拍了2张、3张，脸颊渐渐变红了，眼睛藏起来了。啊，因为眼罩要素很重要，所以把眼罩好好地写进去固定了。当然，也不要忘记用低角度拍摄胸部和臀部，使其成为色狼肉体。辣妹乳房和朴素系爆乳的排列是最棒的。</p><p>“是的，和平♪”“啊，哇，哇……”</p><p>是习惯了吗，是被变态相机影响了吗……把相机对准的话会给我拍姿势的眼睛隐藏酱。我多拍点来缓解一下紧张。</p><p>“好可爱啊！”</p><p>看，这个啊，这个啊，谢谢叔叔，谢谢你♡“</p><p>“哇，我是这样的脸……嗯♡</p><p>总觉得有点奇怪……但是好久没和咲希聊天了……叔叔也不害怕“</p><p>眼窝在看着这边。嗯，视线在下面，眼睛在叔叔的胯间说。因为写了几张无意义的色鬼，所以那个很有效吧。嗯，没办法，如果你那么感兴趣的话。嗯嗯，好不容易才交往到最后吧。</p><p>“啊，接下来是卡拉OK吗？”</p><p>“喂，来了！</p><p>文学部的时候也不怎么去咖啡店玩呢</p><p>小萌也在这里。喂，喂！“</p><p>用力推的比奇辣妹。那是绝对预想到这之后的流程的脸。当然，就这样回去也没有大叔的感觉。瞄准的猎物打算好吃到最后。</p><p>“嗯，嗯……如果只是一点点的话。”</p><p>因此，我来到了车站前相当大的卡拉OK店。开始拥挤还差一点吗，让看起来很闲的工作人员完成接待后进入单间。</p><p>“哇，我唱的是——，这个和这个，小萌呢？</p><p>嗯，嗯，啊，我们一起二重唱吧！“</p><p>友好地选择曲子的两个人。眼窝酱也开始觉得被拍照是理所当然的，反应很淡。虽然有点寂寞，但在这张完成的照片上写上“卡拉OK BOX中裸体是礼仪”。</p><p>“诶，诶！？”</p><p>女学生理所当然地开始脱衣服说：“那么，在唱歌之前，先……”。看着那个吃惊地拿着输入歌的控制台凝固的眼睛隐藏酱。</p></div>,
#  <div id="original-output" style="display:none;"><p>“咦，小萌也不脱吗？</p><p>这是礼仪吗？”</p><p>“啊！？</p><p>那样的裸体……那个，但是，卡拉OK BOX里面裸体是礼仪……那个，有吗？</p><p>咦，咦？？」</p><p>也许是因为用变态相机拍摄的次数还很少吧，因为常识改变和原来的常识而混乱的眼罩。在这期间，女生连内裤都拔出来了。啊，脱下来的衣服叠好放在长椅的边上。</p><p>叔叔也已经赤裸裸地点了果汁和点心。因为用变态照相机改变了，所以工作人员应该完全没有问题。因为享受了几次相似的炖菜，所以没关系吧。</p><p>“啊！？</p><p>啊，啊……哇，啊，男人的那个……“</p><p>“你看，小萌不脱就不能唱歌。”</p><p>那个那个地，剥掉朋友的制服赤裸裸的女学生。嗯，不输给褐色乳房的眼窝酱的爆乳，叔叔的儿子瞬间也变得精神起来了。</p><p>“哇！？</p><p>啊，啊……变得那么大方了。“</p><p>被裸体的事多亏了变态照相机变得不怎么在意了，不过，被叔叔的小鸡钉住了的大白眼隐藏。用双手遮住通红的脸，从眼睛的缝隙中窥视这边的动作很可爱呢。</p><p>“听我的歌啊啊啊啊啊啊啊啊啊啊啊！”</p><p>另外，卡拉OK好像是正常开始的。女学生唱得很好，大叔还算顺利，眼窝虽然声音很好，但是因为在意大叔的胯间没办法，所以中断了很多。是相当快乐的卡拉OK。</p><p>“好的，下一个是小萌。”</p><p>把麦克风交给目隐回到椅子上的女学生。把自己的果汁喝干，擦到这里来。</p><p>“怎么样，怎么样？</p><p>我的歌♪“</p><p>“哦，太棒了。还有……”</p><p>“嗯，我知道大叔的视线去了乳房……嗯，我也差不多想要这个了。”</p><p>一边说着那样的话，一边钻进眼前的女学生。呵呵，乳房的触感，派斯利做几次都可以。</p><p>“啊，哼！？</p><p>咲希！？？”</p><p>当然，被唱歌的目隐酱盯着看，吓了一跳。哎呀，小目隐就这样就好了，但是如果被卡拉OK的工作人员吵闹的话就不好了，所以用变态相机来安装平时不在意的效果吧。</p></div>]

# %%
#中文翻譯_list[66]

# %%
#org_name = '牛娘の乳搾り'


def 寫成文檔(中文翻譯_list_in, n):
    path = 'C:\\Users\\user\\Desktop\\JYPUTER_試做\\' + org_name
    if not os.path.isdir(path):
        os.makedirs(path)
    n="%03d"%n
    
    name = path+"\\"+org_name + '__'+str(n)+'.txt'
    
#    f = open(name, 'w', newline='\n', encoding="utf-8")
    for i in 中文翻譯_list_in:
#        print('第'+str(n)+'章\n')
        #用a而不是用 w 是因為要 for 寫入
        f = open(name, 'a',  newline='\n', encoding="utf-8")
#        f = open(name, 'w+',  newline='\n', encoding="utf-8")
        for jjj in i :
#            print(jjj)
            jjj_spilt=re.split('。', jjj.text)
#            print("-------------------")
#            print(jjj_spilt)
            for j in jjj_spilt:
                j=j.replace("愚息",'金棒')
                j=j.replace("猎奇",'cheat')
                j=j.replace("腮红",'cheat')
                j=j.replace("芒果",'小穴')
                j=j.replace("曼科",'小穴')
                j=j.replace("愚蠢的气息",'金棒')
                j=j.replace("龙猫",'黏呼呼')
                j=j.replace("滑板",'史萊姆')
                j=j.replace("克里特里斯",'陰核')
                j=j.replace("蒲公英",'金棒')
                j=j.replace("面包",'砰砰')
                j=j.replace("好球",'伊庫')
                j=j.replace("波尔奇奥",'子宫颈')
                j=j.replace("poruchio",'子宫颈')
                j=j.replace("阿索科",'金棒')
                j=j.replace("阿索科",'金棒')
                j=j.replace("阿海基",'阿黑')
                j=j.replace("愚气",'金棒')
                j=j.replace("凯茨小穴",'屁股小穴')
                j=j.replace("曼子",'小穴')
                j=j.replace("奶昔",'高潮')
                j=j.replace("通货紧缩",'sex friend')
                j=j.replace("哈莱姆",'後宮')
                j=j.replace("尖晶石",'乳交')
                j=j.replace("灰泥",'乳交')    
                j=j.replace("愚蠢",'金棒')
                j=j.replace("睡取",'寢取')
                j=j.replace("塞弗雷克斯",'sex')
                j=j.replace("流石",'不愧是')
                j=j.replace("人妻科",'人妻小穴')
                j=j.replace("睡着的",'寢取')
                j=j.replace("愚笨",'肉棒')
                j=j.replace("manko",'小穴')
                j=j.replace("睡懒觉",'寢取')
                j=j.replace("法悦",'喜悅')
                j=j.replace("凯茨曼性爱",'屁股sex')
                j=j.replace("凯茨曼睡姿",'屁股sex')
                j=j.replace("妻子科",'妻子小穴')
                j=j.replace("睡下",'寢取')
                j=j.replace("提心吊胆",' 逼嚕嚕 ')
                print(j)
                
                if(j!=''):
                    f.write(j)
            f.write('\n')
#            f.write('-----------------------')
            f.write('\n')
            print('\n')
        f.close()

# %%
# 中文翻譯_list

# %%
# for i in 中文翻譯_list[5]:
#     print(i.text)

# %%
count=1
for ii in 中文翻譯_list:
        print('第'+str(count)+'章\n')
#        print(ii)
        寫成文檔(ii,count)
        count+=1
# Out:
# 第1章
#
# 我在拍卖网站上买了一个奇怪的相机
# 外观是旧的即时照相机
#
#
#
# 商品的标题是变态照相机
# 把拍的女人变成下流、痴女、贱人喜欢的梦想相机
# 据说是这样
#
#
#
# “因为中了彩票，有几年可以玩的钱，所以不能在网上冲浪
# ”
#
#
# 有了钱最先买的是奇怪的色情物品
# 今天从邮购网站送到纸箱的时候，稍微回到了本源，黄昏了
#
#
#
# 虽然明显是开玩笑，但是发现的时候情绪高涨了……眼前有一台可以一只手收起来的既不便宜也不高级的普通相机
#
#
#
# “嗯，因为是马马虎虎的价格，所以只用一次吧
# ”
#
#
# 嗯，正好放学时间很近
# 确实，在离公寓十几分钟左右的商业街和住宅街的交界处，有和女高中生擦肩而过的地方
#
#
#
# “不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不不
#
#
# 因此，我穿着出去散步的风中没有妨碍的服装上街了
# 一只手是宝莱坞相机
# 这个时候觉得奇怪的是被害妄想吗
#
#
#
# 稍微有点内疚的感情和做了点不好的事情的兴奋感让我情绪高涨起来了
# 哦，然后在不受欢迎的小巷里发现了一个穿着制服的女孩子
#
#
#
# “啊，可以拍张照片吗？”
#
#
# “呀！？”
#
#
# 果然，突然拍照不好，试着打招呼
# 嗯
# 好像得到了OK
# 也许吧
#
#
#
# “得到了OK
# 那么，好的
# ”
#
#
# 从后面被打招呼，把回头的女孩子装进照相机的框架里
# 飘扬到膝盖以下的裙子，虽然凹凸感很少，但是奢华的身体有清洁感的水手服，长发的成熟但还算可爱的脸，真好啊
# 是的，啪啪
#
#
#
# “诶，诶！？”
#
#
# 闪光灯在一瞬间发光，突然出现了感光纸独特的光泽照片
# 虽然比想象的要早，但是照片还是白色的
#
#
#
# 穿着制服的女孩子吓得僵硬了
# 好像不用叫警察了，这样的话道歉的话能原谅我吗？……嗯，显影开始了吗，雪白的表面慢慢地出现了女学生的身影……
#
#
# 照片上是穿着制服的女孩子
# 当然，但是有不协调的感觉
# 确实，在拍照之前在框架上看到的制服裙子应该是膝下连胸都没有的感觉
# 但是，照片中的样子，是只有大腿左右的迷你裙，从制服上也能看到的乳房
# 有D吗
#
#
#
# “哦，真的！？”
#
#
# 周围的人也不介意，大声地看着眼前的女学生，确实和照片一样的迷你裙，气氛也变得有点色情了
#
#
#
# 女生只是被拍照吓了一跳，没有注意到制服和身体发生了变化的样子
#
#
#
# “突然对不起，对不起，我拿到了想要的即时相机，所以无论如何都想尝试一下，大叔，因为不认识可爱的人，所以不知不觉就跟你打招呼了，只是想拍照，所以拍的照片全部给你，真的，拜托了，再让我拍张照片
# 喂，喂，拜托了
# “
#
#
# 是的，我跪下拜托你了
#
#
#
# 我看起来很弱，可以吗？
#
#
# 从低角度的迷你裙能看到里面的东西，是非常好的景象……不，不，不是那里，女高中生的表情很困惑，不过，再稍微能去
#
#
#
# “啊，嗯……稍微有点……”
#
#
# 逼真的土下座第三次就去了
# 做人就行
#
#
#
# 哎呀，太高兴了，像弹簧一样从土下座直立起来，结果被拉开了距离
# 咕嘟
#
#
#
# “那么，重新振作精神准备好相机
# 变态相机的效果和刚才拍的一样是真的
# 那样的话，乳房……真的，挺起胸膛会怎么样呢？”
#
#
# 啪啪地拍胸部
# 女高中生的D杯稍微有存在感的乳房在1周画，不，2周左右大的照片出来了
# 这已经可以说是巨乳了
#
#
#
# 「？？？」
#
#
# 女生虽然有什么不协调的感觉，但还是没有注意到自己身体的变化
# 在实际调查中，胸部让水手服高涨，看到了肚脐
# 啊，水手服的长度也变短了吗
# 好厉害的变态照相机
#
#
#
# 虽说没有行人，但这里也是上学的路，所以不能花太多时间
# 啪啪啪啪地从各种角度拍摄
#
#
#
# “哦！
#
#
# 好啊
# 好啊
# “
#
#
# 整体拍照的话制服的长度会变短，拍胸围的话胸部会变大，低角度拍摄的话臀部和大腿会变得丰满，内衣也会从白色的内裤变成红色的蕾丝，可能是影响了里面的东西，表情也很朴素，看起来很认真的气氛渐渐崩溃，脸颊上挂着红色难道是有H的感觉吗？
#
#
# （哇！？
#
#
# 比想象中还要性感的样子……再拍几张的话，会不会有让人讨厌的气氛呢？
#
#
# 但是，在行人越来越多的时间段，到这里太可惜了，怎么办？）
#
#
# 总之，我决定把至今为止拍的照片交给你
# 因为知道了效果，所以好像没有必要着急
#
#
#
# “好的，那是约定好的照片，谢谢
# ”
#
#
# “啊，是，是……”
#
#
# 认真凝视着收到的照片的女高中生
# 虽然变得通红，但感觉完全没有厌恶感
#
#
#
# 再推一把就可以掉下来了
# 不吃的饭菜也被称为武士的耻辱，如果有机会的话，还是想一直吃到最后
# 这里没有寄存的地方
#
#
#
# “嗯，可以再拍张照片吗？”
#
#
# 「……是的
# 」
#
#
# （这个，可以去
# 用眼神看这边，绝对想让你多拿点！
#
#
# 叔叔加油哦！！）
#
#
# 虽然试着在比刚才更近的地方拍了一下，但是女高中生的视线越靠近拍摄越有色情的气氛
#
#
#
# 到刚才为止都是色鬼
# 现在的女高中生，下半身丰满的肉肉，裙子已经短到内裤都藏不起来了，上半身更加突出，胸部成长为G、H等巨乳，所以从衣服上可以清楚地看到乳轮和乳轮的形状
# 胸罩也没有了，制服的长度有没有40厘米，乳房下面清楚地窥视着，非常眼福
#
#
#
# 虽然到了这里，但本人对自己的打扮几乎没有违和感
# 神啊变态照相机
#
#
#
# （这个，也许可以踩进去）
#
#
# 追加拍摄的照片也交给女生的话，会仔细看照片上有洞
# 即使分开也能明白，用粗暴的呼吸“哇”和“啊，啊”，用下流的角度拍摄的自己的身体兴奋是完全明白的
#
#
#
# “嗯嗯，很漂亮
# 又漂亮又色情
# 你看，叔叔这里也变得很有精神了
# ”
#
#
# 为了让女学生看到，把自己的裤裆放在眼前
#
#
#
# “谢谢！
#
#
# ……诶，诶！？”
#
#
# （催眠术？
#
#
# 洗脑？
#
#
# 因为是用变态照相机拍摄的，所以脑子里也会因为H而向色情的方向变化
# 这很好
# ）
#
#
# 刚开始很吃惊的女生，马上用粘稠的眼睛盯着裤子的膨胀
# 顺便说一下，大叔几乎没有罪恶感
# 女生也很高兴，自己也很开心
# 所谓双赢的家伙，如果这样就感到罪恶感的话，就不会买那种奇怪的卖抱怨的邮购了
#
#
#
# 第2章
#
# 女生的眼睛离不开叔叔裤子的膨胀
# 也许是因为用变态相机一个劲地拍的影响，变得通红了，但好像很感兴趣地看着这边
#
#
#
# “那个……那个
# ”
#
#
# “嗯嗯，对了
# 我想拍得更好，要不要去酒店？”
#
#
# 话虽如此，试着向还不积极的女生提出大胆的建议
# 即使这样不行，再拍几张的话感觉会掉下来，没关系吧
#
#
#
# “诶！？”
#
#
# 更加脸变得通红凝固的女学生
# 如果跟着这样的大叔勃起的话会怎么样呢，脑子里会不会有超现实主义呢
# 好可爱啊，我想打包带走
# 不，接下来要做吗
#
#
#
# 「……是的
# 」
#
#
# 我还以为要花一点时间，没想到两个人很顺利地点头，就去了附近的酒店
#
#
#
# 因此，与其说是宾馆，不如说是和女生一起进入情人旅馆的房间
# 另外，来这里之前虽然有马马虎虎的行人，但不可思议的是，应该完全是痴女打扮的女学生的服装几乎没有引起关注
# 照相机的常识改变的效果对周围的人也有效，这似乎是很有趣的事情，但现在是和女学生的个别摄影会
#
#
#
# “好啊
# 好啊
# 那下次就躺在床上，对了对了！”
#
#
# 在进入房间之前还留有不安表情的女学生，用变态相机拍了一拍，表情也变得自然了，比路上还要兴奋
#
#
#
# 虽然是室内，但是被汗淋湿而发光的皮肤很粘
#
#
#
# “哇，好漂亮的乳房
# 有弹性，可爱的乳环上有乳头，高芝士……嗯嗯，稍微把脚像M字一样张开，然后……”
#
#
# “啊，那个……这个，是这样的吗？
#
#
# 啊，啊……我明明能看到乳房和内裤，为什么会这样……♡“
#
#
# 在床上露出乳房，用M字开脚摆出害羞姿势的女生，来了
# 嗯，嗯，这个叔叔也得脱
# 突然放下裤子，又摆好相机
#
#
#
# “啊！？
#
#
# 为什么大叔也脱了呢！？”
#
#
# “你觉得只让女生脱身也不公平吗？”
#
#
# 这里是理所当然的表情，理所当然地继续拍照
#
#
#
# “嗯，不公平吗……那就没办法了
# ”
#
#
# （爸爸，男人的，爸爸，爸爸……啊，那么大啊，啊♡）用这样想的表情看着大叔的爸爸的女生
# 好色可爱啊
# 用变态照相机不停地拍，让他更色情吧
#
#
#
# “咦，我一直盯着你看，你有兴趣吗？”
#
#
# 把勃起的小鸡鸡拿到眼前
# 是个叫让我看看的家伙
# 是的，啪啪
#
#
#
# “嗯……小鸡
# 这是我第一次在这附近看到
# ”
#
#
# 突然，用照相机拍下了近距离看着小鸡鸡而安心的女生的脸，就会出现被小鸡鸡摩擦而露出恍惚表情的女生的照片
# 这是反映了女生的愿望吗？
#
#
# “哎呀，叔叔的小矮子能让你这么高兴真高兴
# 对了，作为照片的谢礼，小矮子，你可以随便做
# ”
#
#
# 自己开心地品尝着小鸡鸡的照片
# 试着和看得到的那个的女学生打招呼
#
#
#
# “哇！？
#
#
# 啊，啊……啊，可以吗？”
#
#
# 用变态照相机被改变了的常识和留在头上的常识不同而混乱吗，虽然有点疑问形，但是身体好像完全在寻求小鸡鸡，用自然的动作拔出内裤跨到了大叔的上面
#
#
#
# 紧紧地把那里和内裤连接起来的透明的爱液，张开嘴握住大叔的金棒兴奋的女学生
# 好的角度再加一张
#
#
#
# “嗯……啊♡”
#
#
# 也许是那一张是最后一次按了吧，在快门的同时坐下，一下子就把小鸡鸡吞下去了吧
# 喂，这是女学生的第一次买的东西，是不是用变态照相机把阴道也改造成了小鸡用的？
#
#
# “咦？
#
#
# 为什么是我♡
#
#
# 腰停不下来♡
#
#
# 啊，啊♡
#
#
# 但是，但是，因为是感谢所以好吗？
#
#
# 啊，啊，啊♡“
#
#
# 明明流着处女的血，却完全不在意，咯吱咯吱地活塞着腰喘着气
# 看起来很老实的女生在2、3个小时后变身为德斯凯维奇，真是个变态的相机
#
#
#
# “哇！
#
#
# 女生真是好色之徒啊
# 用大叔的小矮子不断地变帅就好了
# 我给你拍很多照片吧
# “
#
#
# 叔叔也不甘示弱地挺起腰反击
# 体位也交换用攻击的姿势一边接吻一边是tanepass！
#
#
# 哇哦！
#
#
# 用漫画紧紧地勒紧榨取精子！？
#
#
# 大腿、臀部、乳房、阴道都很有嚼劲，连拍照都忘了，互相挥着腰
#
#
#
# “嗯♡
#
#
# 啊，啊♡
#
#
# 我会的！？
#
#
# 会有什么来的♡！？“
#
#
# 哎呀，女学生难得的第一次H纪念
# 如果这里不好好拍个哈梅的话，就把扔在床上的变态相机一只手把金棒紧紧地放进去，尽情地放进去
#
#
#
# “啊啊啊啊啊♡
#
#
# 在里面♡
#
#
# 好厉害啊♡！！！“
#
#
# 从那以后，再过两个小时
# 在被爱液和精液弄得乱七八糟的床上，不收拾散落的哈梅照片，和女学生一起玩得很开心
#
#
#
# “啊，啊♡
#
#
# 好厉害♡
#
#
# 好厉害♡
#
#
# 小鸡鸡很厉害♡
#
#
# 我，我，喜欢小鸡鸡♡
#
#
# 小鸡鸡是这么舒服的东西呢♡
#
#
# 啊♡
#
#
# 哈哈♡“
#
#
# 也许是因为用相机拍的缘故吧，自己的小鸡鸡也耐力无限，无论做多少次都像银的超级小鸡鸡一样，真是太感谢了，太可怕了
#
#
#
# “喂♡
#
#
# 寿司的味道很好
# 嗯，嗯♡……喜欢这个味道♡“
#
#
# 女学生毫不犹豫地用嘴打扫着粘糊糊的小鸡鸡
#
#
#
# 已经完全是喜欢小鸡鸡的维奇女学生了
#
#
#
# “哦，哦！？
#
#
# 怎么用舌头……稍微放松一下，嗯……出来！？”
#
#
# “啊♡
#
#
# 就像喷泉一样♡
#
#
# 但是，叔叔的金棒看起来还很健康
# 你可以多拍几张
# 也请给我很多小朋友的感谢哦♡“
#
#
# 代替回答给她拍了一张满是精液笑着的女学生
#
#
#
# “啊，我是大叔
# 好久不见！”
#
#
# 买了变态相机之后不久的某一天
# 像往常一样在街上猎物……呵呵，在找被摄体的时候被这样搭话了
#
#
#
# 在行人还很少的道路上，有两个自己和茶色头发、小麦肌的辣妹般的女儿，夹着它晒黑的查拉男
# 我正往这边走，你认识这样的姑娘吗？
#
#
# “哦，女生
# ”
#
#
# 想起了回忆
# 这是买变态相机那天第一次拍的女生
# 完全，bitch贴在木板上一瞬间不知道是谁
#
#
#
# “谁？”
#
#
# 旁边的查拉男
# 哇，有2米啊
# 肌肉质地是扎竿角色的感觉
#
#
#
# “嗯，不久前承蒙关照的sex friend叔叔？”
#
#
# 虽然是爽快地说炸弹发言的女学生，但是对方好像也特别普通，一般都会被打招呼说“啊，谢谢”
#
#
#
# “阿酱，比那样的事早点去吧
# ”
#
#
# “嗯，那就和朋友乱打，叔叔也再打吧——哈哈♡”
#
#
# 女生好像也很享受bitch生活
#
#
#
# “啊，最后一张
# 好的
# ”
#
#
# 让我拍一张和他们分手
# 在冲洗出来的照片中，在宾馆使用过的避孕套散落的床上，从女阴和肛门滴下精液，高兴地笑着和平的女学生的画
# 今后一定会享受一整天吧
# 也有这样的功能吗
# 很有趣的变态相机
#
#
#
# 照片好好地放在包里，自己也去寻找今天的猎物
#
#
#
# 第3章
#
# 买了一两个月的变态相机后，今天也没有好女儿摇摇晃晃地走在公园附近的路上
# 因为得到了拍摄的对方的身体和心到服装都变成色鬼的变态照相机之后用点心感觉能享乐女孩子，最近不太用力拍照，2，3日慢慢地坐着瞄准了
#
#
#
# （嗯，虽然是很内行的独白，但是做的事情只是搭讪而已
# 能享受各种各样的女孩子是很好的，但是想要有什么变化
# 照相机的使用方法也已经知道了很多，接下来……）
#
#
# 一边想着，一边走在冷清的住宅区
# 今天稍微改变一下心情，来到了至今为止没有来过的高级房子林立的地区
# 因为之前发现了用照相机的绝技走在哪里都不会被认为不自然的方法，所以试着伸长了脚
#
#
#
# “那里的下级市民迷路了
# 请带我去这附近适合我吃午饭的地方
# ”
#
#
# 原以为完全没有行人，结果突然被搭话了
# 回头一看，不合时宜的大小姐盯着这边站着……嗯，大小姐站着
# 这是一个穿着金发、看起来很高级的制服、看起来很高飞车的少女
#
#
#
# “嗯，用手机应用……（虽然长得很漂亮，但是看起来很麻烦）”
#
#
# 再稍微这样，深窗的千金来了，这样，清秀系？
#
#
# 因为期待着，所以想正常应对，赶紧离开
#
#
# “我不会这么做的
# 应用程序？
#
#
# 因为我总是让他在周围做
# “
#
#
# 旁若无人的样子
# 现实中竟然有这样的角色，反而让人佩服
# 但是，为什么要和自己打招呼呢……啊，用相机不让人觉得不自然是反效果吗
#
#
#
# 依然盯着我命令的大小姐
# 好吧，今天的猎物就是这个姑娘好吗
#
#
#
# “说起来，你竟然跟我打招呼……”
#
#
# 拍了一张大小姐的照片，在出来的照片上用笔写着警戒心下降
# 拍了几个人之后才注意到，在用变态相机拍的照片上这样写文字的话，常识改变和催眠洗脑就会在那个方向上起作用
#
#
#
# 今天出门前也写了用镜子拍自己是理所当然的人物
# 虽然不知道通用到什么程度，但像现在这样即使是初次见面也不会产生不信任感，被搭话是不会被警戒的
# 然后，再用写给大小姐的文字……
#
#
# “你随便拍什么照片！？”
#
#
# 虽然是生气的大小姐，但途中却露出了忘记对什么生气的表情
# 嗯嗯，好像很顺利
#
#
#
# 「咦，给你指路的报酬……嘛，那就原谅他吧
# 」
#
#
# 即使是相当勉强的说明也会这样接受
# 是相当方便的功能
#
#
#
# “对了对了，好了
# 啊，弄错了，好了
# ”
#
#
# 首先，为了慎重起见，要反复写下警戒心
#
#
#
# “又来了！？
#
#
# 嗯，感觉有点奇怪……“
#
#
# 再拍照片，写上巨乳化和屁股大
# 如果不特别写的话，以拍摄的地方为中心，会随机地变得色情
# 虽然这样就可以享受了，但是因为这次想到了，所以要写在追加味道和提高大小姐胸围的照片上
#
#
#
# 嗯，在普通的照片上写色鬼单词无论做多少次都很色情
#
#
#
# “那嚒，我带你去适合小姐的地方吧
# ”
#
#
# “已经这样了，下贱的东西……快点吧
# ”
#
#
# 还是抱着胳膊生气的大小姐
# 但是，没有注意到用变态照相机拍到的手臂被遮住的丰满、有质量的乳房和突然变成鞭子的臀部和大腿……真是令人眼福的景象啊
#
#
#
# “嗯？
#
#
# 有什么……“
#
#
# （哎呀，大小姐的样子
# 距离比刚才更近两三步……虽然皱着眉头，但是脸颊也稍微变红了，和预想的一样
# 虽然本人没有注意到，但好像已经变成了很好的味道了
# ）
#
#
# “咦，有味道吗？对不起
# 因为是在外面走，所以出汗了
# ”
#
#
# “嗯♡……诶，诶！？
#
#
# 我没有闻到味道
# “
#
#
# 大小姐好像闻得很香，连问都没问就自爆了
# 慌忙退到后面一步，为了慎重起见，再追加一点吧
#
#
#
# 拍下慌慌张张的大小姐，同样写上追加味道
# 现在的大小姐应该是因为在意大叔的体臭而在意的状态
#
#
#
# “嗯♡！？
#
#
# 啊，照片是……啊，啊♡
#
#
# 什么都有啊♡“
#
#
# 故意靠近一看就会让人觉得甜蜜麻木的快感和无法把握为什么会变成这样的混乱混杂在一起的表情
# 顺便说一下，大小姐好像涂了花色系的香水，靠近的话能享受到清凉感的香味和稍微汗流浃背的香味混合在一起的很好的味道
#
#
#
# （呵呵，看了那样的裤裆，大叔好像勃起了
# 比想象中还要傲娇变态的大小姐看起来也很好吃
# 这个看起来很值得期待啊
# ）
#
#
# 就这样带着女儿去公园里
# 当然，用变态相机拍了好几张照片，再加上变态性习惯，在本人没注意到的时候，就变成了以色狼体型为味道的魔佐性习惯的变态大小姐
#
#
#
# “餐厅还没开门吗！？”
#
#
# “啊，到了
# 是这里吧
# ”
#
#
# 在横穿公园的另一侧的出入口附近，虽然不是很大，但偶尔会带大小姐参观承蒙关照的建筑物
#
#
#
# 也许是因为变态照相机的力量，也许是因为太自然了，所以一般都带进去了，但是在不愧是中回到了我的大小姐
#
#
#
# “什么，什么！？
#
#
# 这里不是厕所吗！？
#
#
# 而且，男人用的……嗯♡
#
#
# 什么味道♡“
#
#
# “咦，有什么问题吗？”
#
#
# 即使嘴上说否定的话，也不会特别出去，露出了有点期待的表情
# 已经被变态照相机变成了变态，被带到男厕所里却扭动着大腿（用变态照相机改成超迷你裙）汗流浃背的大腿
#
#
#
# 即使想牵着手去单间，也完全没有警戒心，做好了准备
#
#
#
# “好的，现在准备坐在这里，啊，拍一张吧
# 最喜欢精液的变态女
# ”
#
#
# 把马桶盖抬起来，稍微强行让大小姐坐
# 最后用变态照相机拍的照片给现在的大小姐写了非常合适的文章
#
#
#
# “嗯♡！？…啊，啊♡
#
#
# 我为什么坐在这里……啊，啊♡“
#
#
# 用湿润的眼睛仰望这边的大小姐，完全发情了呢
# 嗯嗯，那就按照约定，给最喜欢精液的变态大小姐提供最适合的美味吧
#
#
#
# 在大小姐面前解开腰带，放下裤子的拉链，取出自己的金棒
#
#
#
# “那么，好的
# 小姐最喜欢的装满精液的金棒，让您久等了
# ”
#
#
# 被突出到眼前的勃起小鸡凝固的大小姐
#
#
#
# “啊！？”
#
#
# 在大小姐说什么之前，和小鸡一起拍照，写上最喜欢的东西
#
#
#
# 洗出来的照片是让小鸡在眼前出神地流口水的大小姐的表情，这样的话会很满足吧
#
#
#
# “啊，啊，啊……为什么这么臭……啊♡
#
#
# 啊♡“
#
#
# “上厕所的时候，拿出来的小朋友趁热大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口大口？
#
#
# 大小姐
# “
#
#
# 第4章
#
# 在公园的男厕所的单间里带着大小姐，在眼前把叔叔的金棒拿出来
# 这是在相应的时间外行走的穆雷姆雷叔叔的小鸡鸡
# 因为是用变态照相机拍摄的，所以看起来很好吃，但是常识还妨碍了在小鸡面前凝固的大小姐
# 那我教你肉便器的礼仪吧
#
#
#
# “哦♡”
#
#
# 为了方便涮锅，把鬼头放在大小姐的脸上，用非常可爱的声音叫了我
# 好啊，作为纪念一张
#
#
#
# “什么味道……♡
#
#
# 这是礼仪
# 就像开胃菜一样吧
# 不好好品尝的话♡“
#
#
# 于是，也许是理性的线断了吧，之后就按照欲望把小鸡鸡吃完一样开始品尝
# 用舌头仔细地舔着竿，用嘴可爱地吸取鬼头的忍耐汁，把脸埋在玉里享受味道
# 不愧是大小姐，粗俗的礼仪也很完美
#
#
#
# 止住的时候，嘴巴张得很大，从小鸡的尖端一直吞到了根本
# 明明是把脸埋在叔叔胯下的下流行为
# 你有肉便器的才能啊
#
#
#
# “哦，哦，大小姐，真厉害！”
#
#
# 忘记拍照，把小鸡放进大小姐的嘴里
# 嘴唇的柔软和丰满的舌头的弹力
# 用到喉咙深处为金棒服务
# 以吸着的气势脸颊凹陷是意外的脸色情可爱，不愧是大小姐
#
#
#
# “那么，射精！？”
#
#
# 紧紧抓住大小姐的脸，喉咙深处扑通扑通！
#
#
# 我请你吃特浓精液
# 大小姐的脸颊膨胀，从鼻子和嘴的缝隙中流出了白浊液，大小姐看起来很幸福
# 虽然有掉进马桶的水声，但是这里是厕所，所以没有问题吧
#
#
#
# 一边用舌头品尝着嘴里颤抖着射精的小鸡鸡，一边从射精的旁边发出咕嘟咕嘟的声音吸着精子
# 哦，哦！？
#
#
# 即使射精结束，也要把小鸡中残留的精子吸出来，很有吸引力！？
#
#
# 砰的一声才把小鸡放开
# 大小姐就这样瘫倒在马桶的靠背上，有点发酸，但她的脸看起来很满足
#
#
#
# “哈哈……嗯♡
#
#
# 这就是精液，我最喜欢的精液就是这样的味道♡
#
#
# 非常臭又下流，多么棒啊♡“
#
#
# 拍下从嘴里滴下精液的大小姐的照片，写上肉便器
# 今后因为是小鸡鸡的全程马拉松，为了方便使用，制服、内裤、胸罩都很适合肉便器，所以要改成色鬼服装
#
#
#
# “啊啊啊♡
#
#
# 啊，啊♡“
#
#
# 哎呀，还没到正式演出就变成了肉便器，光是精子的味道就变得受欢迎了吧
# 散落在金发和制服上的白浊液是非常好的声调
#
#
#
# “大小姐，那我请你吃主菜吧
# 啊，你知道肉便器的礼仪吧
# ”
#
#
# 因为不能让您久等了，所以马上拿着大小姐的大腿把小鸡鸡打个洞，擦到内裤对面的女阴上
#
#
#
# “嗯♡
#
#
# 嗯♡
#
#
# 私肉便器♡
#
#
# 可以把阿小穴拿出来尿尿哦♡
#
#
# 请在我的洞里吃很多精液吧♡“
#
#
# 在大小姐说完要睡觉的时候，把腰往前伸，把小鸡鸡插进去
# “嗯”哦♡！！”于是，用照相机紧紧地抓住用非常下流的喘息声叼着小鸡的大小姐，开始活塞
#
#
#
# “喂♡
#
#
# 嗯♡
#
#
# 这就是厕所里的礼仪♡
#
#
# 嗯♡
#
#
# 让陌生的大叔用漫画竟然这么舒服♡
#
#
# 肉便器很棒♡“
#
#
# 也许是个有教养的大小姐吧，那里也是一级品，完美地叼着第一只小鸡，想要引起快感
# 阴道壁的噗噗咯吱咯吱地搓里筋子宫口好好地吸住鬼头！？
#
#
# 虽然喉咙里面也很舒服，但是阿小穴也很厉害！
#
#
# 这位大小姐，是为了小宝宝才有的肉体
#
#
#
# 我忘了这里是公共厕所，请大小姐吃小鸡鸡
# 因为想更深地把小鸡鸡带进去，所以改变了体位，在马桶上坐着抱着大小姐的时候，突然打开了单间的门
#
#
#
# “是谁……啊，真的吗！？”
#
#
# 我好像忘记锁门了
# 大小姐也突然来了客人，身体一下子僵硬了，但是好像赢不了抬起来的小鸡鸡！？
#
#
# 啊，啊……啊！？”一直发出娇声
# 嗯，因为是在厕所用马桶的地方，所以没有必要慌张吗
#
#
#
# “喂，现在这个肉便器正在使用中，再等一下
# ”
#
#
# “肉便器！？”！？
#
#
# 啊，啊，你在用肉便器吗，那就等着吧
# “
#
#
# 和微笑着进来的大叔打招呼，大叔好像也接受了
# 因为变态相机的常识改变，即使在人前H也不会引起骚动，这是值得庆幸的地方
# 在厕所里把小鸡鸡塞进肉便器是理所当然的
# 以大小姐为中心形成了这样的常识
#
#
#
# “啊♡
#
#
# 啊，啊♡
#
#
# 被我的女阴砰砰地吐槽作为肉便器被使用的所见！？
#
#
# 啊♡
#
#
# 啊♡
#
#
# 非常有感觉呢！？
#
#
# 请再多看看我♡“
#
#
# 马佐的大小姐用画廊的视线更加发情激烈地寻求着小鸡鸡
# 单间的门开着，外面也有回响的声音，可以等3个人以上的顺序
#
#
#
# 在服务中脱下制服，乳房和接合部分都要露出来
# 随着砰砰砰砰、肉和肉碰撞的声音，巨乳化的乳房也慢慢地心情舒畅地摇晃着
# 越是用变态相机拍摄越会变成下流色情的肉体，这样的话大小姐最喜欢的小鸡鸡也会变多吧
#
#
#
# “嗯♡
#
#
# 嗯♡
#
#
# 太棒了♡
#
#
# 在男性厕所发出下流的声音♡
#
#
# 好厉害啊♡♡！！！“
#
#
# 最后用手抓住单间打开的门，用背包决定中出射精
# 厕所要好好使用
# 嗯，虽然从接合部分溢出来了很多，但是因为掉在马桶里所以是安全的，大小姐的爱液飞到了门外，不过是服务
#
#
#
# “啊♡
#
#
# 看，请拍吧♡
#
#
# 被精液弄脏了♡
#
#
# 被男性的金棒使用而高兴的肉便器的样子♡“
#
#
# 之后让排队等候的大叔们使用了大小姐
# 人数很多，一次3p，4p和嘴，胸，屁股等身体全身都在为小鸡服务，不过，被小鸡包围变成非常喜欢的精液沾满气味儿，作为mazo肉便器的大小姐也是希望的吧
#
#
#
# “啊，叔叔♡”
#
#
# 那之后过了几天的中午，吃了饭在公园里放松的时候和大小姐再会了
# 虽然是和那个时候一样的制服，但是设计清秀的上衣，乳房的形状让人明白，裙子也没有遮住抓住感觉很好的屁股
#
#
#
# 并且，大小姐代替寒暄举起裙子，大腿上挂着的魔术的下流的留言和不是从里面滴下来的汗的透明的粘液非常适合
#
#
#
# “嗯，接下来是在那个厕所每天的服务
# 请一定要用叔叔哦♡”
#
#
# 优雅微笑的大小姐
# 好像很享受作为肉便器的生活
#
#
#
# 当然在那之后，根据邀请在厕所里使用了肉便器
# 这次作为选项，改造成母乳也能吹出来也不错
#
#
#
# 第5章
#
# “好像是上了隔壁城市的高中
# 变态相机叔叔
# ”“诶，真的吗？”“嗯嗯，弟弟在上学，大家都在说话”“是那个吧，进学校堂堂正正地拍照，却没有人报警，就这样出去玩的变态大叔”“仅此而已？”？
#
#
# 怎么说呢，听说你要做色情的事？”“是吗？
#
#
# 但是，因为也没有成为新闻，所以除了拍照以外没有问题吧？”
#
#
# 早上上学的时候，因为风纪委员的活动在校门前巡视的时候，在院子里发现了3、4个人聚在一起开始聊天的学生们
#
#
#
# “就算是传闻也没有更好的了吗？是的，虽然还有时间，但还是赶紧去教室……”
#
#
# 我们的高中应该是相应的升学学校，但也不是没有这样的话题
# 因为这也是风纪委员的工作，所以想和小组打招呼让他们进入校舍，但是校门外面变得吵闹起来，回头一看，有一个现在成为话题的变态相机叔叔
#
#
#
# 嗯，长裤和衬衫，去公司太随便了，但也不是不在街上的普通大叔的样子
# 只是，这里是学校前面，手上拿着一个像波拉洛伊一样的照相机
# 怎么看都是变态者
#
#
#
# 不躲藏，堂堂正正地环视着女学生们，对着照相机（……啊，老师们不在，怎么办？）
#
#
# “今天要拍哪个孩子呢？总之，适当地拍一下……”
#
#
# 考虑到这一点，因为开始正常拍照，所以不由得跑过去阻止了
#
#
#
# “喂，喂！？
#
#
# 没有关系的人的摄影是不行的！
#
#
# 我会叫警察的！？”
#
#
# “嗯，一张左右
# 好的，好的
# ”
#
#
# 完全不听我的话，把相机对准我的大叔
# 嗯，完全是变态者啊……
#
#
# “啊！？”
#
#
# （照相机的闪光灯比想象的还要强，吓了我一跳
# 总之……啊，那个，仔细看的话可能会喜欢吧？
#
#
# 不不不不不不不不不不不不不不不不不不不不不不不不不不不不
#
#
# 果然，是波拉洛伊相机啊，拿着我的照片的变态相机叔叔
# 虽然有点奇怪，但总之作为风纪委员必须注意，让他出去
#
#
#
# “嗯，因为是即时照相机，所以不会留下，拍的照片会交给本人或者扔掉
# ”
#
#
# 又拍了照片，写了点什么交给我
# 收到的照片上写着“爆乳化”、“大叔的兴趣”，但没有什么特别奇怪的
# 咦？
#
#
# 虽然我没有动手，但我会努力把一个劲地拍照的大叔从校门前拿开
#
#
#
# “嗯♡”
#
#
# （我为什么只是被别人拍照，却发出奇怪的声音，有点奇怪……嗯，总觉得被这个大叔拍照的话胸部和大腿会变得狭窄
# 但是我的胸围是H罩杯，所以从衣服里露出来是理所当然的，总之，家庭房间的时间也快到了）
#
#
# “嗯，如果是照片的话，我以后会让你拍的……诶，我说什么！？”
#
#
# “那么，今天晚上9点在这里碰头吧
# ”
#
#
# “啊，有点……嗯，算了，以后再和老师商量吧
# ”
#
#
# 不由得这么一说，大叔干脆把相机收起来就走啦
# 嗯，我完全没有那种想法，怎么看都是变态，为什么我会说那样的话呢
#
#
#
# 通红地走进校舍
# 也有听了这话赶来的风纪委员的成员，先把他们赶走，告诉他们什么都没发生
# 总觉得，大家的视线……但是，除了被拍照以外，没有什么特别奇怪的事情
#
#
#
# 结果那天因为变态相机叔叔的话题而吵得不可开交，男生用相当讨厌的眼神看了看，也不知为什么忙着应对，连和老师商量都忘了
# 大家都好好遵守风纪吧
#
#
#
# “嗯，我为什么会按照约定来……也没能对老师说，总觉得从早上开始就感觉到了视线……”
#
#
# 晚上9点，我暂时回家，悄悄地来到了校门
# 本来不打算来的，我明明是风纪委员却违反了这样的校规……
#
#
# 闪光灯和照相机的声音
# 当然，早上的变态照相机叔叔也在
#
#
#
# “啊，不要再拍了！？”
#
#
# 先来到校门前的大叔一看到我就笑着拿着相机啪啪
# 哎呀，为什么是这么奇怪的大叔，如果不坚强的话，什么都会听的
# 不管怎么说，因为喜欢……咦，感觉有点奇怪，可能是心理作用吧
#
#
#
# “嗯，不是说好现在就很好吗？”
#
#
# “嗯，不，约定……没办法，满足了就不要来学校了！”
#
#
# 是啊，不能违背约定，作为风纪委员是为了保护学校的风纪，这是理所当然的吧？
#
#
# “嗯嗯，让我拍到满意就好了
# ”
#
#
# 我从叔叔那里收到了现在拍的照片
# 对学校的制服稍微吃惊了的我的脸……裙子到膝上是短的东西吗？
#
#
# 之后写着“如果被拜托的话什么都会听的”
# 虽然觉得有点奇怪，但还是普通的照片
#
#
#
# “好啊！
#
#
# 那个傲娇的表情很好！
#
#
# 再来一张
# 啊，我也是
# “
#
#
# 帕沙、帕沙、帕沙在校门前被大叔拍照
# 因为已经过了放学时间，所以几乎没有行人，但还是很不好意思
#
#
#
# 总觉得胸和大腿都被勒紧了……啊，从这个角度拍的话就能看到内裤了！？
#
#
# 啊，如果是只有大腿的裙子的话，一般拍也能看到……那可以吗？
#
#
# 是啊，制服短的不能去吧
# 制服的下摆露出了一半的乳房
# 嗯，我很在意胸大
#
#
#
# 只是被拍了写有“色鬼服装”、“爆乳化”、“露出性习惯”、“雌奴隶”的照片，却觉得做了不该做的事情
#
#
#
# “啊，啊♡……也已经很满足了吧？
#
#
# 那我就这样……“
#
#
# （每次被拍照的时候身体都会变热，虽然有点奇怪，但总之要从这里逃出来……）
#
#
# 再被拍下去的话，可能会走到无法挽回的地方，不由得这么说了
# 照片也拍了很多，这样约定就实现了吧
#
#
#
# “嗯，这次是边散步边拍的，带着这样的东西来的，不是很期待‘散步’吗？”
#
#
# 叔叔很遗憾，但是拿着像领导一样的东西笑着
# 咦，里德从叔叔的手到我的脖子……
#
#
# “嗯！？”
#
#
# （咦！？
#
#
# 为什么是我的项圈！？
#
#
# 咦，那个！？
#
#
# 但是，如果被抓住了领导就不能违抗♡
#
#
# 想被命令♡）
#
#
# 叔叔的手和里德一起戴着项圈，非常开心地笑着摆出狗的姿势
# 啊，啊……散步♡
#
#
# 如果叔叔命令我的话我会怎么样呢♡
#
#
# 第6章
#
# “那我们去散步吧，我也给你拍很多照片
# ”
#
#
# “啊，啊♡
#
#
# 哈哈♡“
#
#
# 只要拉上引线，心脏就会心跳加速，如果让我命令的话就不行了
# “散步”，像狗一样散步是第一次，在那之前忘了想什么就回答了
#
#
#
# 匍匐着和主人的叔叔开始“散步”
# 擦肩而过的人稀稀拉拉地看着，大家看了一次好像没有什么问题地过去了
# 只是在散步，不奇怪吧
# 但是，不认识的人的视线，稍微看一下体温就会上升，这么舒服
#
#
#
# “喂，你喜欢看吗？”
#
#
# “是的……感觉到别人的视线，身体变热了，漫画纯被淋湿了……”
#
#
# （诶，诶！？
#
#
# 为什么我这么说！？
#
#
# 但是，因为是真的所以很舒服所以没有问题吧♡）
#
#
# 不知什么时候脱下制服变成了内衣的样子，但是完全不在意
# 因为，在“散步”的过程中大家的视线聚集在一起♡
#
#
# “自慰一周要做多少？”
#
#
# “到现在为止一周2,3次……”
#
#
# 我现在绝对是一副讨厌的表情
# 只是在“散步”中被问到了普通的事情♡
#
#
# 但是，身体很热很舒服
# 能看到和拍照都很舒服，所以没办法
#
#
#
# “啊，那个人，用非常厉害的眼神看着你
# ”
#
#
# 来到公园的深处，无家可归的人聚集在一起看着我
#
#
#
# “啊，嗯♡……啊，啊♡”
#
#
# “太棒了
# ”
#
#
# 叔叔俯视着瘫在地上的我跟我打招呼
# 咦，是主人来着
# 心浮气躁
#
#
#
# “是的……太棒了
# ”
#
#
# “内裤湿透了，脱了吧
# 被那个人看着
# ”
#
#
# 如果被命令把相机对准的话就没办法了
# 无家可归的人们也聚集在一起，让大家看着被我的爱液淋湿的内裤……光是想象就知道从那里流出来的色情液在大腿上流淌
#
#
#
# “啊♡
#
#
# 啊♡
#
#
# 一边被看，一边说谎，我不穿内裤了♡
#
#
# 啊……“
#
#
# 大家都在看♡
#
#
# 为了能让大家更多地看，登上长椅，张开脚，自己啪嗒啪嗒地把那里也摊开
#
#
#
# “那么，就在这里拍哈梅吧
# 最喜欢了吧
# ”
#
#
# 叔叔给我的照片上写着非常喜欢拍哈梅的文字和邋遢的笑容的我
#
#
#
# （是，拍哈梅……那个，明明不知道却明白了意思，可以一边做爱一边拍照♡
#
#
# 啊————♡！？
#
#
# 只是想象一下就好了♡）
#
#
# 已经没有遮挡的东西了，从那里飞溅出一股害羞的汤汁吧
# 自己做的手淫也没有变成这样♡
#
#
# 我变态♡
#
#
# 是被看到曝光而高兴的雌奴隶♡
#
#
# “看，他们也在看
# ”
#
#
# 叔叔用手指的地方是闪闪发光的眼睛、眼睛、眼睛、眼睛♡
#
#
# “啊，啊♡”
#
#
# “是的
# ”
#
#
# 用相机拍的瞬间，我的那里突然有一种破膜进入的感觉♡
#
#
# （嗯♡
#
#
# 真厉害♡
#
#
# 我♡
#
#
# 明明是处女♡
#
#
# 被不认识的人看到，用不认识的主人的小灯笼第一次夺走♡
#
#
# 真厉害♡
#
#
# 很舒服♡
#
#
# 能看到很舒服——♡）
#
#
# 在公园里，被连名字都不知道的大叔（主人）揉着我下流的乳房和臀部，让我放进小窝很舒服♡
#
#
# 一边被看，一边被拍一边做爱的变态的我最适合的第一次♡
#
#
# （呵呵，无家可归的大叔们，把裤子放下……咦，是个小胖子啊♡
#
#
# 在我那里，让我犯下的小鸡♡
#
#
# 大家看到我都很兴奋
# 那样，拼命地移动手♡
#
#
# 拍哈梅很棒♡）
#
#
# 在长椅上举起我的叔叔邀请我再靠近周围的人看看
# “啊，可以吗？”无家可归的人们走得很近
# 啊，大家都一边打嗝一边靠近，射精了吧
# 从我周围的小鸡鸡开始♡
#
#
# 精液♡
#
#
# 一边看着被侵犯的地方，一边被大家盯上了小鸡♡
#
#
# 我，我♡
#
#
# “哦，你是个通情达理的人
# 嘘，你调教得这么变态
# ”
#
#
# “原来不是吗？
#
#
# 看，出了这样的汤很高兴“
#
#
# 进出我漫画的叔叔的金棒也讨厌地看着我的身体，做着勃起的小鸡的画廊
#
#
# “哈哈♡
#
#
# 嗯♡
#
#
# 我变态♡
#
#
# 是最喜欢看的变态♡
#
#
# 啊，啊，啊——♡“
#
#
# 从啪啪啪啪的拍摄方到周围散落的照片都变得很舒服
#
#
# “啊，啊♡
#
#
# 请拍照♡
#
#
# 也喜欢被拍照♡
#
#
# 看我所有H的地方♡“
#
#
# 乳房、那里、臀部的洞都要看哦♡
#
#
# 我是风纪委员，如果知道这样的话♡
#
#
# “啊，色情
# ”“可以吗？
#
#
# 已经停不下来了？”“看着小鸡鸡，露出了讨厌的笑容！
#
#
# 我会揍你的！”“我也好，我也好，都要用精子标记那个下流的碎布！”
#
#
# “啊♡
#
#
# 啊，啊♡
#
#
# 被看到了♡
#
#
# 能看到我的优点♡“
#
#
# 大家都随便在我身上撒上热腾腾的东西，叔叔也同时射精到里面，脑子一片空白♡
#
#
# 注意到的时候是早上
# 虽然不记得是怎么回去的，但是好好地在家的床上洗澡，好像也没有被家人发现，一般换上制服正常上学
#
#
#
# 虽然感觉周围的视线比昨天更集中，但是和昨天晚上的那个相比有点不足
# 风纪委员的伙伴也有什么奇怪的表情，但好像没有什么特别的问题，和昨天一样开始了早上的巡视
# 紧紧贴在乳房上的制服为了能再拿起来，故意把胳膊放在头上，看到了叔叔从校门走来
#
#
#
# “啊！？
#
#
# 明明说好了不会再来的！”
#
#
# “啊，不，不，不满足……”
#
#
# 那就没办法了……没办法
# 嗯，在变态大叔袭击其他学生之前，作为风纪委员必须满足
#
#
#
# 因为是为了保护风纪的活动，所以当场把叔叔的裤子放下，拿出昨天让我心情舒畅的金棒
# 在家庭房间开始之前必须快点休息
# 但是，直到满足为止……好好地做到最后也没有问题吧
#
#
#
# “嗯♡
#
#
# 这个灯笼♡
#
#
# 昨天射精了那么多♡
#
#
# 很凶♡
#
#
# 扰乱风纪的小鸡鸡一定要好好地咬一口让他满足♡“
#
#
# 昨天天黑了，看不清楚，但是很大，拿得那么大，却很硬，叔叔的金棒很棒♡
#
#
# 周围有男生盯着看，把自己裤子的裤裆鼓起，那边也有扰乱风纪的可能性，以后一定要拔掉哦♡
#
#
# “啊……嗯♡
#
#
# 嗯，嗯“♡……嗯♡
#
#
# 嗯……嗯……嗯……“嗯……嗯……”
#
#
# 首先用嘴，到最后也可以，但还是想要那里，把屁股伸出来睡觉了
#
#
#
# “想在这样的学校的正中间被侵犯，风纪委员真是变态啊
# 在那里黏糊糊的一天就能品尝到小鸡鸡的味道
# 这样的话，不知道哪个更想满足
# ”
#
#
# 虽然这么说，但是叔叔从后面尽情地给我插入了小鸡
# 就这样，像抱起来一样举起来，让上学的大家看到♡
#
#
# “啊♡
#
#
# 啊，明明不行♡
#
#
# 我明明是风纪委员♡
#
#
# 这样的变态行为♡
#
#
# 一边被大家看到♡
#
#
# 太棒了♡
#
#
# 在校门前和大叔做爱的地方被看到了——♡“
#
#
# 叔叔手堵得拍不出来，而是让大家用手机拍我
# 每次发出啪啪的声音，闪光灯一亮就会变好♡
#
#
# 太棒了♡
#
#
# 太棒了♡
#
#
# 一起做风纪委员的男生和同学旁边座位的女生都能看到♡
#
#
# 在叔叔满意之前射精了很多，最后被拍到了校门旁边的精子呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧呼哧
#
#
# “嗯，很满足
# 那嚒，剩下的就交给你了
# ”
#
#
# 虽然叔叔很满意地出去了，但是这次必须把周围男生的小鸡鸡拔出来
# 虽然保护风纪也很辛苦，但是这也是工作，所以没办法
#
#
#
# 第7章
#
# “啊，是大叔！”
#
#
# 「咦，诶……是谁？」
#
#
# 在某个地方听到了这样的声音，回头一看，站着一个似曾相识的辣妹和一个不认识的校服姑娘
# 啊，这里是第一次使用变态相机时的小巷吗
#
#
#
# 几次H的女生改，bitch辣妹
# 习惯了相机之后转了很多圈，感觉真的好久不见了
# 旁边的是学校的朋友吗
# 普通的制服膝下的裙子，头发是黑发很好的半长，不过，是有意地伸长刘海的朴素可爱的眼罩
# 虽然和现在的小辣妹组合很不协调，但是和第一次见面时的气氛很搭呢
#
#
#
# “没关系吗？
#
#
# 在学校也不要跟着不认识的人……“
#
#
# “没关系，没关系！”
#
#
# 和叔叔玩了好几次的sex friend，是朋友哦
# 喂……啊，拍照太好了
# “
#
#
# “你是朋友吗？”
#
#
# “那个，虽然和小萌的班级不一样，但是到去年为止都是在文艺部一起的
# 啊，因为只有3个部员，所以年末就废部了
# ”
#
#
# 和和气地说话的大叔和同学不知道该怎么办才好，慌慌张张的眼睛藏着
#
#
#
# 看来，废部之后就疏远了，好久没在校门前见面了，所以一起回去了
# 大概，废部后用变态照相机拍了很多，所以眼窝好像很困惑
# 但是，我会好好听你的话，很好
# 嗯嗯，这里叔叔帮你脱一身吧
#
#
#
# “对了，要给你拍几张纪念照吗？”
#
#
# 把变态相机对准两个人
# 眼窝可能是在警戒第一次见面的大叔，但是比奇辣妹会笑着在相机上摆出姿势，给我做双拍子
# 另外，为了不让眼窝逃跑而压抑着
#
#
#
# “看，奶酪，奶酪！”
#
#
# “啊，嗯！？”
#
#
# 啪嚓一声
# 嗯，拍到了感觉很好的好朋友的纪念照片
#
#
#
# 拍女生的时候也是这样的反应啊，一边怀念一边拍着两个人
#
#
#
# “啊！？”“视线，视线♪”“那么，哇……”“嗯，这是什么……？”“哇，哇，啊♡”“好厉害吧♡”
#
#
# 叔叔的相机技巧♡“
#
#
# 随着拍了2张、3张，脸颊渐渐变红了，眼睛藏起来了
# 啊，因为眼罩要素很重要，所以把眼罩好好地写进去固定了
# 当然，也不要忘记用低角度拍摄胸部和臀部，使其成为色狼肉体
# 辣妹乳房和朴素系爆乳的排列是最棒的
#
#
#
# “是的，和平♪”“啊，哇，哇……”
#
#
# 是习惯了吗，是被变态相机影响了吗……把相机对准的话会给我拍姿势的眼睛隐藏酱
# 我多拍点来缓解一下紧张
#
#
#
# “好可爱啊！”
#
#
# 看，这个啊，这个啊，谢谢叔叔，谢谢你♡“
#
#
# “哇，我是这样的脸……嗯♡
#
#
# 总觉得有点奇怪……但是好久没和咲希聊天了……叔叔也不害怕“
#
#
# 眼窝在看着这边
# 嗯，视线在下面，眼睛在叔叔的胯间说
# 因为写了几张无意义的色鬼，所以那个很有效吧
# 嗯，没办法，如果你那么感兴趣的话
# 嗯嗯，好不容易才交往到最后吧
#
#
#
# “啊，接下来是卡拉OK吗？”
#
#
# “喂，来了！
#
#
# 文学部的时候也不怎么去咖啡店玩呢
#
#
# 小萌也在这里
# 喂，喂！“
#
#
# 用力推的比奇辣妹
# 那是绝对预想到这之后的流程的脸
# 当然，就这样回去也没有大叔的感觉
# 瞄准的猎物打算好吃到最后
#
#
#
# “嗯，嗯……如果只是一点点的话
# ”
#
#
# 因此，我来到了车站前相当大的卡拉OK店
# 开始拥挤还差一点吗，让看起来很闲的工作人员完成接待后进入单间
#
#
#
# “哇，我唱的是——，这个和这个，小萌呢？
#
#
# 嗯，嗯，啊，我们一起二重唱吧！“
#
#
# 友好地选择曲子的两个人
# 眼窝酱也开始觉得被拍照是理所当然的，反应很淡
# 虽然有点寂寞，但在这张完成的照片上写上“卡拉OK BOX中裸体是礼仪”
#
#
#
# “诶，诶！？”
#
#
# 女学生理所当然地开始脱衣服说：“那么，在唱歌之前，先……”
# 看着那个吃惊地拿着输入歌的控制台凝固的眼睛隐藏酱
#
#
#
# “咦，小萌也不脱吗？
#
#
# 这是礼仪吗？”
#
#
# “啊！？
#
#
# 那样的裸体……那个，但是，卡拉OK BOX里面裸体是礼仪……那个，有吗？
#
#
# 咦，咦？？」
#
#
# 也许是因为用变态相机拍摄的次数还很少吧，因为常识改变和原来的常识而混乱的眼罩
# 在这期间，女生连内裤都拔出来了
# 啊，脱下来的衣服叠好放在长椅的边上
#
#
#
# 叔叔也已经赤裸裸地点了果汁和点心
# 因为用变态照相机改变了，所以工作人员应该完全没有问题
# 因为享受了几次相似的炖菜，所以没关系吧
#
#
#
# “啊！？
#
#
# 啊，啊……哇，啊，男人的那个……“
#
#
# “你看，小萌不脱就不能唱歌
# ”
#
#
# 那个那个地，剥掉朋友的制服赤裸裸的女学生
# 嗯，不输给褐色乳房的眼窝酱的爆乳，叔叔的儿子瞬间也变得精神起来了
#
#
#
# “哇！？
#
#
# 啊，啊……变得那么大方了
# “
#
#
# 被裸体的事多亏了变态照相机变得不怎么在意了，不过，被叔叔的小鸡钉住了的大白眼隐藏
# 用双手遮住通红的脸，从眼睛的缝隙中窥视这边的动作很可爱呢
#
#
#
# “听我的歌啊啊啊啊啊啊啊啊啊啊啊！”
#
#
# 另外，卡拉OK好像是正常开始的
# 女学生唱得很好，大叔还算顺利，眼窝虽然声音很好，但是因为在意大叔的胯间没办法，所以中断了很多
# 是相当快乐的卡拉OK
#
#
#
# “好的，下一个是小萌
# ”
#
#
# 把麦克风交给目隐回到椅子上的女学生
# 把自己的果汁喝干，擦到这里来
#
#
#
# “怎么样，怎么样？
#
#
# 我的歌♪“
#
#
# “哦，太棒了
# 还有……”
#
#
# “嗯，我知道大叔的视线去了乳房……嗯，我也差不多想要这个了
# ”
#
#
# 一边说着那样的话，一边钻进眼前的女学生
# 呵呵，乳房的触感，派斯利做几次都可以
#
#
#
# “啊，哼！？
#
#
# 咲希！？？”
#
#
# 当然，被唱歌的目隐酱盯着看，吓了一跳
# 哎呀，小目隐就这样就好了，但是如果被卡拉OK的工作人员吵闹的话就不好了，所以用变态相机来安装平时不在意的效果吧
#
#
#
# 第8章
#
# 女生一边用柔软的乳房夹着大叔的小鸡鸡，一边若无其事地面对朋友
# 只是这个已经色情的小麦色的乳房和小鸡和手扭曲的形状
#
#
#
# “嗯？
#
#
# 等着的时候吃点东西？
#
#
# 没关系，叔叔绝伦，也有小萌的份儿♡“
#
#
# 女学生不顾吃惊的朋友开始了排版
# 褐色皮肤的乳房用唾液顺滑松软弹力厉害，举起着手臂
# 这样的话，真的会在一首歌中射精
#
#
#
# “啊，啊！？
#
#
# 那样，但是很厉害♡
#
#
# 咲希用那样H的脸，第一次看到……哇，哇哦♡“
#
#
# 目隐好像不是曲子的地方
#
#
#
# “嗯，嗯♡
#
#
# 叔叔的小鸡鸡，我开动了♡
#
#
# 中♡
#
#
# 啊，H的味道♡
#
#
# 钾也很粗，想起让我心情很好，我也很兴奋♡
#
#
# 喂，射精，射精♡
#
#
# 叔叔的浓痒啊♡“
#
#
# “哇，味道到此为止……金棒是这么讨厌的味道♡
#
#
# 啊，啊……用乳房那么动看起来很好吃♡
#
#
# 嗯，我，我……♡“
#
#
# 拿着麦克风摇摇晃晃地靠近女学生的另一侧，看着朋友的灰熊而着迷的眼窝
# 喂，用另一只手开始摆弄那里了呢
#
#
#
# “哇！？
#
#
# 灰熊变好了呢……这个好像马上就要射精了……！”
#
#
# 从乳房的山谷中看到的鬼头吐出白浊液
# 褐色皮肤和白色精液的对比很好
# 因为用变态照相机增强着射精还不停止，女学生的乳房，脸，头发，制服也湿透了
#
#
#
# “啊♡
#
#
# 叔叔的最榨……嗯♡
#
#
# 很浓♡
#
#
# 嗯……好像是精液的味道♡“
#
#
# “啊，啊♡
#
#
# 男人会变成那样♡
#
#
# 闻到这种色情的味道的话，我，我……啊♡“
#
#
# 眼窝好像只闻到了精液的味道
# 真享受色鬼啊
#
#
#
# “已经是小萌了，放着麦克风偷窥手淫真是没礼貌
# ”
#
#
# “啊！？
#
#
# 对不起……但是，咲希的，那个，太色情了……忍不住“
#
#
# 沾满精液的辣妹和汗流浃背的制服女孩紧贴在一起，展开了非常色情的景象
#
#
#
# “这里是卡拉OK店，你看，握着麦克风♡”
#
#
# “啊，啊啊啊！？
#
#
# 这个，这是叔叔的……喂，小鸡
# “
#
#
# 看着趋势，女学生把眼睛藏在这里……哇！？
#
#
# 刚拿出来的敏感的地方，眼罩的手，呼吸也很粗暴，真是太痒了
#
#
#
# “啊，非常热♡
#
#
# 这么大的……喂，在女孩子中……♡“
#
#
# “光看着就没意思了
# 你看，就按照小萌喜欢的那样用小麦克风享受吧
# ”
#
#
# 女学生的建议好像也没听进去啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊
# 因为是很好的角度，所以拍了一张纪念照
#
#
#
# “嗯♡
#
#
# 好厉害♡……我很小气……寿司的味道♡
#
#
# 啊，啊♡……手停不下来……♡“
#
#
# “看，看，麦克风要好好用嘴使用！”
#
#
# “嗯♡
#
#
# 啊，啊♡
#
#
# 亲了小鸡♡……喂♡
#
#
# 和想象的一样H的味道♡
#
#
# 好吧，因为是卡拉OK店，所以可以用嘴对着麦克风♡
#
#
# 喂，喂♡
#
#
# 叔叔的小鸡鸡很好吃♡
#
#
# 哈哈♡“
#
#
# 拍了几张照片后，不知是不是完全掉了，张着大嘴，整个嘴都开始品尝金棒
# 哦，从一开始就很高水平
# 这本来就有知识啊
#
#
#
# “用舌头太厉害了！？”！？
#
#
# 大叔马上就要射精了！？”
#
#
# 哎呀，听了很厉害的射精单词，不是把脸放开，而是把嘴唇咽到了小鸡的根本
# 那么，如您所愿！
#
#
# “嗯哼！？
#
#
# 嗯，嗯“♡♡！！！
#
#
# 喂，嗯♡“
#
#
# 和刚才一样射精都喝了
# 连小鸡的根本都咬住了，却隐约可见的眼窝湿润的眼睛好可爱啊
# 再来一张
#
#
#
# “嗯”♡
#
#
# 嗯♡……嗯♡“
#
#
# “啊，全部都喝了
# 我也分一下吧，喂♡”
#
#
# “嗯！？
#
#
# 嗯♡
#
#
# 嗯，嗯♡……嗯♡“
#
#
# 用沾满精子的嘴女孩子们的接吻
# 好啊，好啊
# 叔叔拍了很多照片
# 也许是尝到了眼窝口中残留的精子，一脸满足地笑着的女学生
#
#
#
# “小萌的嘴，精液的配菜非常好吃哦♡
#
#
# 啊，这次轮到叔叔的曲子了吧
# 那么……“啊！？”是的！”
#
#
# 抱着目隐坐在对面椅子上的女学生
# 把自己的阿曼和眼窝的阿曼展开，准备好像万事俱备
# 两个人都湿透了，连前戏的必要都没有
#
#
#
# “好的，那么首先，给这个新产品想要的流口水的人……！”
#
#
# “嗯♡！？
#
#
# 到里面！？
#
#
# 进来了哦♡“
#
#
# 为了满足目隐的希望，发出了非常好听的娇声
#
#
#
# “啊♡
#
#
# 这样小萌也一样啊
# 再玩很多吧♡“
#
#
# “啊♡
#
#
# 好厉害♡……嗯，咲希♡
#
#
# 咲希♡
#
#
# 好好地贯穿在我心中♡
#
#
# 嗯♡！！！“
#
#
# 里面好是好事啊
# 拍的照片上写着棒姐妹、sex friend朋友
# 那么，这次就做朋友想的色鬼漫画吧
#
#
#
# “嗯♡
#
#
# 叔叔小鸡鸡这边也放进去了♡
#
#
# 这个♡
#
#
# 这个♡
#
#
# 非常舒服♡
#
#
# 好厉害啊♡
#
#
# 更多，更多♡“
#
#
# 嗯，这边已经是100次以上的历战肉洞了，大叔的肉棒也很从容地叼进去，想要紧紧地榨取
# 啊，当然，眼窝也不会忘记，用手指轻轻地解开臀部
#
#
#
# “啊啊啊♡
#
#
# 那里，不是！？
#
#
# “
#
#
# “啊♡
#
#
# 你的屁股被抠得好厉害
# 小萌♡
#
#
# 绝对屁股的人也很喜欢♡“
#
#
# 两个都不偏不倚地放进小鸡，大家一起享受
#
#
#
# “啊，啊♡
#
#
# 啊♡
#
#
# 会发出声音♡
#
#
# 但是，因为是卡拉OK所以大声叫也没关系吧♡
#
#
# 嗯♡
#
#
# 子宫入口浑浊，子宫颈♡
#
#
# 再多吃点子宫颈♡“
#
#
# “嗯♡
#
#
# 嗯♡
#
#
# 用小萌的奶瓶，这样做会怎么样呢~♡
#
#
# 啊♡
#
#
# 太可爱了，脸变得很有趣♡
#
#
# 好啊♡
#
#
# 好啊♡“
#
#
# 结果在那之后，延长了3个小时，大家都很期待卡拉OK的H
# 偶尔回到基本上也不错
#
#
#
# “嗯♡
#
#
# 热腾腾的中出哦♡！！“
#
#
# 最初的战战兢兢的气氛到哪里去了，没有羞耻也没有传闻地尖叫着的眼睛隐藏酱
# 和已经长了好几次的女生在精液的游泳池里幸福地重叠在一起，叔叔也非常满足
#
#
#
# “哇♡
#
#
# 嗯♡
#
#
# 已经吃饱了♡
#
#
# 下次再见吧
# 这次我来介绍一下sex friend的哥哥们
# 用很多小鸡乱打也很开心哦！“
#
#
# “啊，啊♡
#
#
# H是这么舒服的东西……啊，对了
# 书签也不邀请吗？”
#
#
# 文化部是3个人吗
# 确实不太好
# 第9章
#
# “哇♡
#
#
# 男式器皿
# 是金棒吗？这么舒服啊♡
#
#
# 竟然请我吃这么多♡
#
#
# 嗯♡
#
#
# 虽然没有做一点，但是请允许我用双手服务
# “
#
#
# 那么，在卡拉OK和女生一起享受眼睛隐藏的一周后
#
#
#
# 在两人的请求下，文化部的最后一个人也读了，召开了三人的欢迎茶会（和用变态照相机使之深信的乱交派对）
#
#
#
# 黑发长发的充满气质的书签拍了一张照片，写着清秀的比奇，和两个人一起充分享受茶会吧
#
#
#
# “书签♡
#
#
# 书签也很开心呢♡“
#
#
# “嗯嗯，书签也一定是♡
#
#
# 我还以为你很在意呢♡“
#
#
# 在清秀比奇的书签的两侧，女学生和眼窝来了
# 当然，这是一种各自以背包和车站便当的形式叼着小鸡的状态
#
#
#
# “嗯，嗯♡
#
#
# 这是第一次茶会的形式，嗯♡
#
#
# 把我的处女散落的地方给这么多人，啊♡
#
#
# 对不起，太舒服了，声音，嗯♡
#
#
# 停不下来♡“
#
#
# “好的，好的！”
#
#
# 乱帕发出粗俗的声音，嗯♡
#
#
# 心情变好是礼仪哦♡“
#
#
# “对了对了♡
#
#
# 因为很舒服所以没办法啊♡“
#
#
# 被小鸡包围的好朋友3人组互相笑着
# 叔叔也会提高打在腰上的小鸡鸡的速度
#
#
#
# “嗯♡
#
#
# 是这样啊……嗯♡
#
#
# 啊，啊♡……我的叔叔的金棒和双手的金棒都很害怕♡
#
#
# 请变得更舒服♡
#
#
# 请给我热腾腾的款待♡！！！“
#
#
# “嗯♡
#
#
# 中柱♡
#
#
# 再加一点♡
#
#
# 我也想把它倒进子宫里♡“
#
#
# “啊，啊，啊♡
#
#
# 能和大家乱打，我也很开心♡
#
#
# 来吧♡
#
#
# 里面和外面都是粘糊糊的，让我心情舒畅♡！！“
#
#
# 正如请求的那样，把小鸡塞进清秀比奇的深处，把精子灌进去
# 奇迹般地全员的射精是同时的吗，从3人的那里很好地精液喷出，周围也有湿漉漉的精液
#
#
#
# 这次选哪个好呢
# 如果是这个样子的话，可能会一直拖到天亮，所以我一边想着3个人的3个洞都可以享受比较一下，一边拔出小鸡，冲进了下一个洞
#
#
#
# 第10章
#
# “谢谢你今天聚集过来！”
#
#
# 活动会场的小规模会议室
# 虽说是会议室，但桌子和椅子都收拾好了，只剩下墙壁上的几个行李架
#
#
#
# “和往常一样，严禁触摸
# 不打扰别人，不吵架
# 遵守规则享受cosplay的乐趣吧！”
#
#
# 在拿着照相机的男性们的中央，穿着某个游戏的cosplay服装的女孩子健康地宣言着
# 周围的人也情绪高涨，对女孩子的宣言！的欢呼声
#
#
#
# 是的，今天改变心情去了cosplay摄影会
# 因为本来就没有照相机的兴趣，所以到现在为止都不知道有这样的活动
# 还没玩过cosplay H呢，在网上冲浪到达的网站上有可以马上应征的地方，真是运气好
#
#
#
# 虽然想着用小的波拉洛伊相机进入摄影会怎么样，但是拿着专业的相机的人本身，连一半都没有，所以比想象的要轻松
# 不要在意周围的人，好好地拍照吧
#
#
#
# “最初是舞酱最新版的服装！
#
#
# 啊，姿势指定从高级会员开始按顺序
# “
#
#
# 是格游戏的角色吗
# 即使是日式的，胸部和大腿都露到了极限
# 非常性感帅气的服装
#
#
#
# 高级会员，在网站上看的时候位数和通常不同，的加奇势的各位当然在最前排不知为何拿着望远镜一样的照相机啪啪啪啪地开始拍摄
# 另外，照相机的快门声音和偶尔进入的姿势指定左右，礼仪相当好
#
#
#
# 自己也决定先用变态相机拍摄
# 因为在很好的时机改变姿势和方向，所以全体参加者都能充分满足的分配
# 不愧是有名的cosplayer
# 据说全名叫科斯子
#
#
#
# “嗯，今天大家的视线都很热烈吧
# 有点火辣辣的
# 换装的同时也要降温了
# ”
#
#
# 大概30分钟左右吧，脸颊渐渐变红，眼神也变得奇怪了，换了衣服
# 虽然周围有点担心科斯子的身体状况，但是没关系，因为是用变态相机拍的，所以感觉很H
#
#
#
# 因为特别指定是指定的，所以整体上H杯的爆乳是带有肉肉的好身体，乳房自不必说，F左右原本就是巨乳
# 虽然周围的人觉得有点奇怪，但是因为觉得变化后是理所当然的，所以没有什么特别的骚动
# 但是，H的身材加速了是无意识的感觉吗，中腰回不去的人很多呢
#
#
#
# “再见
# 接下来是小光的舞台服装！
#
#
# 这个，丝带和蕾丝很多，很辛苦“
#
#
# 科斯子换了衣服回来了
# 然后，扎瓦的参加者们
# 哎呀，先拍一张照片写下来
#
#
#
# “啊，不能飞行哦！”
#
#
# “对不起，太可爱了，不知不觉
# ”
#
#
# 危险，危险
# 因为爆乳化了，所以乳房完全从衣服上露出来，露出了乳头
# 虽然本人对认识改变并不在意，但如果用变态相机写上平时的服装，不对周围的人推广常识改变的话，就会引起骚动
#
#
#
# “下次要注意哦！
#
#
# 嗯，重新振作精神，开始拍摄！”
#
#
# 拿着麦克风摆出舞台风格的姿势
# 嗯，乳房被胳膊压碎了，非常色情
# 麦克风的位置怎么看都是那个，用变态照相机改变着照相机小子们的常识，大家都站着拍照呢
# 叔叔也拍很多吧
#
#
#
# “穿着高跟鞋就是这个姿势，嗯♡
#
#
# 用奇怪的肌肉发出声音
# 不要再让我胡闹了
# “
#
#
# 一边说着，一边做出相当杂技般的姿势的科斯子
# 周围的高级会员们也很明白吗，开始指定播放爆乳的姿势感觉很好
#
#
#
# 啊，对了，为了在科斯子的背后映出服装房间，按下快门
# 然后在出来的照片的服装房间里画上箭头，写上“色情服装满载”
#
#
#
# “这次是昨天配信的RPG的，那是这样的服装吗？
#
#
# 啊，姿势啊
# 啊♡“
#
#
# 嗯嗯，大家的中心，几乎都是穿着绳子的比基尼盔甲的服装，拿着塑料制的大剑的科斯子
# 即使乳头被遮住，露出的乳圈也非常色情
# 几乎，光秃秃的斗篷上只有手和脚是铠甲，好啊，好啊
# 啪啪
#
#
#
# “怎么了，衣服的尺寸弄错了吧……喘不过气来了
# 那么，接下来是一般会员的姿势指定吧
# ”
#
#
# “啊，请用握着小鸡鸡和平的姿势
# ”
#
#
# 那么，已经足够了吧，全部参加者都用变态照相机拍照，科斯子也是变态，色狼行为也是理所当然的，改变了常识
# 因为正好可以定时指定姿势，所以试着发出一个色情指示
#
#
#
# “嗯，没办法啊……那么，正好在合适的地方的你的
# ”
#
#
# 虽然很嘈杂，但是变态相机的效果好像很好，科斯子和周围的人都觉得有点奇怪，所以顺利地实行了
# 大概是因为会员的触摸是NG的，但是科斯子碰了就OK的理论吧
#
#
#
# “啊，啊！？”
#
#
# 被科斯子放下裤子握着小鸡的高级会员虽然很混乱，但是什么都不能说应该是理所当然的事情就凝固了
# 嗯，第一次乘坐是没办法的
# 让给一直支持科斯子的高级会员们吧
#
#
#
# “是的，和平！
#
#
# 虽然是第一次摸灯笼，但是感觉很奇怪？
#
#
# 已经，奇怪的问题……不是很奇怪吗？
#
#
# 味道很好，虽然很出汗，但是不太讨厌吧……♡“
#
#
# 也许是因为在让她握着小鸡鸡的指示下，科斯子和周围的人都渐渐有了色情的气氛，周围的提问和科斯子的回答都变成了色情
# 感觉很好，但色鬼的改变似乎很有效，以小鸡群为背景，或者是翻过来的和平，或者是从布上展开女阴，都在实行
#
#
#
# “啊，被袭击后摆出的姿势……啊，那是……那么，用肛门！？”！？
#
#
# 咦，肛门不是NG的……没办法啊♡“
#
#
# 是的，把屁股伸出来摆姿势的时候写上了“肛门OK”
# 这样，没有避孕套也不会弄脏
# 是完全不需要前准备就能插入的神功能
#
#
#
# 因为触感是NG的，所以科斯子自己握着坐在椅子上的会员的小鸡鸡坐下来
# 因为是辣妹系的制服身姿在大家面前抽出裤衩，放入屁股是相当有背德感的画
#
#
#
# “那么，我走了……啊，这不是第一次决定的吗！？
#
#
# 应该是第一次啊
# “
#
#
# 第11章
#
# 用变态照相机常识改变渗透了的cosplay摄影会
# 已经有充分的效果了吗，肛门游戏的要求也几乎没有疑问地通过了
#
#
#
# 竿角色被指名，银银勃起的小鸡顺利地进入科斯子的屁股
#
#
#
# 嗯，笑着看着照相机
# 专业
#
#
#
# “嗯……嗯……那个……比想象中还要好♡……轻松地进去……嗯♡”
#
#
# 也许是因为变态相机，一开始稍微停了一下，但之后却突然可爱地屁股下降了
# 另外，虽然努力保持着笑容，但是因为笨拙的笑容和制服主题很容易看到，所以用双手摊开裙子，感觉色情度增加了3倍
#
#
#
# 周围也开始一只手拿着相机啪嗒啪嗒的
# 啊，对了……射精就OK了，写在现在拍的插入肛门的科斯子的照片上
#
#
#
# “啊，啊……今天的cos孩子艾罗”“喂，那不是因为摸不到所以NG吗？”“嗯，虽然很僵硬，但是也想拿相机！
#
#
# 怎么做才好……”“拜托摆个姿势就OK了吗？”“那就请高级会员们加油吧”“你们这帮家伙，真是个好主意！”
#
#
# 好像也很受会员们的好评
#
#
#
# 插入小鸡鸡的人也已经到了极限，叔叔也支持着写下了“全身性感带”、“精液嗜好”、“发情状态”、“不能拒绝被说的话”
#
#
#
# “这个，科斯子
# 可以请你摆个姿势吗？”
#
#
# 啊，有勇气的高级会员去了哦
#
#
#
# “啊，没关系，不过……你是开玩笑吗？”
#
#
# “好的，谢谢！”“太好了！
#
#
# 神是存在的！”“我和我都很好呢！”“真的是一直拍得最好的照片！”
#
#
# 说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着说着
#
#
#
# “啊！？
#
#
# 诶？？？
#
#
# 热……哇♡
#
#
# 为什么，我……啊，呀♡……每次被喷精液的时候身体都会变热！？“
#
#
# “哇！？
#
#
# 科斯子的屁股被吓到了……嗯，对不起，已经不能忍耐了！？“
#
#
# 哎呀，放在肛门里的小鸡鸡好像也超过了极限，不输给被打的量
#
#
#
# “嗯♡
#
#
# 屁股♡
#
#
# 屁股里面也有哦♡
#
#
# 明明是摄影会♡
#
#
# 我也很厉害♡！！！“
#
#
# 不知道是不是突然瘫软了，保持中座状态的科斯子又瘫在地板上了
# 精液游戏和照相机的快门都停不下来，所以情况很混乱
#
#
#
# “啊♡
#
#
# 嗯，不行！？
#
#
# 出来了♡
#
#
# 因为现在屁股还在扩大♡
#
#
# 啊，啊♡
#
#
# 嗯！？”
#
#
# 从漂亮的光屁股喷出的白浊液
# 明明是你的脸却变成这样了呢
# 拍了几张照片，写上“用照相机拍的和放小鸡一样”、“人气和精液的量一样”、“今天特别感谢，触摸解禁”
#
#
#
# “嗯，虽然让人看到了有点可怜的地方，但还是换了衣服，这是我最喜欢的雪风酱的衣服哦！
#
#
# 今天特别的触摸解禁！
#
#
# 大家要配合cos子酱输的拍摄哦！
#
#
# 啊，不能吵架啊
# 请遵守顺序
# “
#
#
# 不愧是有名的cosplayer
# 虽然有那么多的瑕疵，但是换了衣服的话会被好好地重新设置的哦
#
#
#
# 还有，因为变态照相机变成了爆乳，所以贫乳角色的忍者服装只是支撑着乳房的存在
# 对小鸡鸡感觉很好
# 周围的会员们也已经准备好了裸照，随时准备临战（乱交H）
#
#
#
# “啊，好的
# 那就去吧……会去的吧
# ”
#
#
# 跨越会员No.1的20多岁的青年，呼哧呼哧地喘着粗气坐下的科斯子
#
#
#
# “果然是处女？”
#
#
# “笨蛋，一定是第一次决定的吧！”！
#
#
# ……这本书禁止性骚扰发言
# 嗯，角色的风格很好！”
#
#
# 因为变态照相机的常识改变，感觉很奇怪，但是好像没有问题地前进
# 啊，尽情地走了
# 多亏了相机，我觉得和肛门一样没有什么问题
#
#
#
# “嗯……哇♡
#
#
# 进来了……啊，摄影……嗯♡“
#
#
# 忍耐着破瓜的疼痛笑着的科斯子和啪啪啪啪地按下快门的会员们
# 两个都很有毅力
#
#
#
# “那么，我也打扰了！”“啊，这次用手，用手！”“拜托您了！”
#
#
# “啊，这样的话大家都来吧！
#
#
# 嗯♡
#
#
# 在里面磨破了……嗯，小灯笼在里面被拍了，这么舒服♡“
#
#
# 这个好像要花很长时间才能转到这里
# 首先要好好地集中在拍摄上吧
#
#
#
# 啪啪，啪啪地和普通会员们一起拍哈梅，不，是收化妆品吗？
#
#
# 哪个都行
# 热衷于拍照
#
#
#
# “啊♡
#
#
# 身体会跳♡
#
#
# 再多花点♡……嗯♡
#
#
# 精液♡……啊，啊，啊♡……好像会变成cos的习惯♡“
#
#
# 这是一幅很难看到的画
# 大家也像被缠住了一样活动着腰，对着照相机热衷着
#
#
#
# “嗯♡
#
#
# 好像很喜欢cosplay H♡……啊，啊♡
#
#
# 再加点小鸡鸡吧♡
#
#
# 啊，啊啊♡
#
#
# 虽然衣服脏了，但是被精液泼了很舒服♡“
#
#
# 每10人左右夹着服装交换，轮到自己的是索沙盖公主的服装？
#
#
# 是个有个性的家伙
# 当然，用变态照相机露出乳房，穿有洞的内裤随便放，用口交脸的请求让我拍了很多
#
#
#
# “嗯♡
#
#
# 嗯……哇哦♡
#
#
# 哇，我的口交脸是这样的♡
#
#
# 嗯♡……也能马上看到波罗的海照相机就好了♡
#
#
# 嗯”♡
#
#
# 喂，口交脸也很可爱的科斯子……嗯♡
#
#
# 用小鸡不回答♡“
#
#
# 然后，让我享受了3个顺序
#
#
#
# “啊啊啊，哈哈……带来的全部都是精液♡
#
#
# 但是今天的摄影会很成功呢！
#
#
# 那么，大家下次也请多多关照！”
#
#
# 那么辛苦的1对40左右的乱交结束后一定会回来的……cosplayer好厉害
# 还有，会员们也爽快地收拾了会场，表情舒畅地回去了
#
#
#
# 虽然整体上很有趣，但是竿的角色太多了，几乎只拍了相机
# 下次试着考虑一下能好好享受的方向吧
#
#
#
# 第12章
#
# “喂，你看！
#
#
# 好厉害，好厉害
# “
#
#
# 大概是上小学的时候吧，把头发扎成双马尾的女孩子划着公园的秋千玩得很开心
# 明亮的裙子和印花衬衫全面展现了孩子的风格
# 虽然母亲也在旁边看着，但是女孩子尽情地荡秋千也不会甩到那里，所以会守护着是否破坏平衡吧
#
#
#
# 真是令人微笑的风景
#
#
#
# “小蓝
# 请好好握住我的手
# ”
#
#
# “嗯
# ”
#
#
# 不知道是不是买东西回来了，把放着食材的塑料放在长椅上，稍微担心地看着女儿的妻子
# 身高很高，梳着长长的头发，穿着朴素的衬衫和格子裙，给人一种妻子的感觉，身材是一个孩子？
#
#
# 不认为是生了的波丘本是相当的优秀的材料
#
#
#
# “哎呀，是买东西回来的吗？”
#
#
# “啊，嗯？……啊，原来是邻居啊，你好
# 今天是节日，所以和女儿出去买东西了
# ”
#
#
# 刚才，在不被注意到的距离用变态照相机拍了母女，和亲密的邻居写了下来，所以好像没有问题地被搭话了
#
#
#
# “蔬菜很痛，差不多该回去了
# ”
#
#
# “嗯
# ”
#
#
# “零食的时间快到了，可以吗？”
#
#
# “回去！”
#
#
# 这是令人微笑的母女的对话
# 嗯，今天就吃这个母女吧
#
#
#
# 一边这样想着，一边笑嘻嘻地看着母女的对话，在正好的时机打招呼
#
#
#
# “啊，看起来很重
# 要拿吗？反正是隔壁
# ”
#
#
# 「哎呀，真是不好意思，因为每天都这样
# 」
#
#
# 虽然被委婉地拒绝了，但好像没有什么坏感情
# 在这里再推一推
#
#
#
# “我只是为了减肥出去散步，你看，我只带了相机，好像也能做正好的运动
# ”
#
#
# “叔叔拿的是照相机吗？”
#
#
# 哎呀，好像钓到了双胞胎
# 那么，啪啪
#
#
#
# “是啊
# 好的！”
#
#
# “呀！”
#
#
# 和吓了一跳的妻子一起走到前面，看起来很有趣地观察着宝莱坞相机的双胞胎
#
#
#
# 比想象中还要自由奔放的性格
# 我很有趣地看着出来的照片被冲洗出来的样子
#
#
#
# “好厉害！
#
#
# 和智能手机不同的是纸的照片！
#
#
# 开始了！！”
#
#
# 虽然突然拍照是粗鲁的，但是因为女儿很高兴，所以妻子叹了口气看着她
# 好了，这次就按照让人好好享受的方向去吧
#
#
#
# “好的好的，妈妈也很为难，回家吧
# 如果可以的话，我回去再给你拍几张
# ”
#
#
# 一下子，在这里拿着买东西的行李，把推特罗利的孩子推到公园的出口
#
#
#
# “真的！
#
#
# 约定！
#
#
# 拍得好可爱啊！”
#
#
# “已经是邻居了，没关系吧
# 那就回去吧
# ”
#
#
# 于是，三个人离开了公园
#
#
#
# “那你老公长期出差去国外？”
#
#
# “嗯，这不是第一次，幸好是家庭主妇
# ”
#
#
# 一边听着没有其他爱的话题的家庭信息，一边走在住宅区
# 不知道是不是因为用照相机很怀念我，扭蛋的孩子不停地挥舞着牵着我的手
#
#
#
# “我想感谢你拿着行李陪我女儿，请你去吧
# ”
#
#
# 被这么说了，笑着说不要那么费心，成功地去了母女家拜访
# 两层楼的一栋房子打扫得也很干净，是理想的家
#
#
#
# 在餐厅请我喝麦茶
# 另外，双胞胎正在和零食蛋糕搏斗
# 母女已经受到了用变态照相机拍摄的不协调感的影响，所以不客气地拍照
# 给正在做家务的妻子写上“在家里做性的事情是理所当然的”，给推特罗利的孩子写上“开心就发情”等调情词
#
#
#
# “喂！
#
#
# 叔叔给我拍了可爱的照片！！”
#
#
# “哎呀，谢谢
# 果然，没有父亲的话会寂寞吗？这个孩子，今天非常健康
# ”
#
#
# “哈哈，这样也没关系
# 因为是单身，所以在这里也能享受到久违的舒适氛围
# ”
#
#
# 笑眯眯地扮演一个好叔叔进行准备
#
#
#
# “对了，小蓝，学校的作业呢？”
#
#
# 「咦……咦？」
#
#
# “夫人好像很忙，我来看看吧？”
#
#
# 对突然失去精神的双子说了句话
# 从双胞胎和妻子的表情来看好像没有问题
#
#
#
# “太好了！
#
#
# 谢谢叔叔！”
#
#
# “已经没办法了，你要有礼貌地看
# ”
#
#
# 就这样成功地进入了双胞胎的房间
# 比想象中还要整洁的房间
# 妻子的教育很好吧
# 床上有书桌和衣柜
# 有玩具箱啊
#
#
#
# “嗯，作业是……算术、国语和理科！”
#
#
# 从书包里精神饱满地取出教科书，但铅笔的前进感觉很慢
#
#
#
# “那嚒，叔叔就用作业进行的咒语给你拍照吧
# ”
#
#
# “啊！
#
#
# 用照片就能完成作业吗！？”
#
#
# “因为是咒语，所以自己好好做是必要的
# ”
#
#
# “嗯
# ”
#
#
# 真是个好孩子
# 拍下在算术作业中写乘法的样子，写上“理解度上升”
#
#
#
# “哇，作业真的变简单了！？”
#
#
# 嗯嗯，那就再多拍点咒语吧
# 再一次在推特罗利孩子的照片上，国语教科书的照片是“学习淫语”，理科教科书是“大人的保险体育”
#
#
#
# “我已经算好了，谢谢叔叔！
#
#
# 那嚒，下次也写点什么很开心“
#
#
# 用好的笑容打开用变态照相机转换了的国语的教科书
# 也许是心理作用吧，脸颊是红色的，也有因为开心而发情的吧
#
#
#
# “嗯，恩乱是这样写的
# 奇怪，变态……叔叔的咒语！
#
#
# 竟然连这么难的汉字都挂上了！”
#
#
# 天真无邪地说出淫语写在笔记本上的女孩子，真好啊
# 叔叔也吓了一跳
# 啊，当然，萝莉和熟女都能吃得很好吃
#
#
#
# 虽然是快乐地做作业的双胞胎，但是语言越来越少，呼吸变得粗暴
# 虽然完全发情了，但是好像不知道自己是什么情况
# 变态照相机的效果好像很好地出来了
#
#
#
# 第13章
#
# 用变态照相机改变了的淫语的学习也好好地结束了，稍微染上脸颊的双子
# 做得很好呢
#
#
#
# “休息一下？”
#
#
# “不，现在很开心……总觉得热乎乎的，轻飘飘的很舒服？
#
#
# 奇怪吗？”
#
#
# “嗯，好像没有问题，作业再做完一点再休息也不错
# 啊，别咒语了，再拿一张吧
# ”
#
#
# 当然，在拍摄的照片上会写上“性兴趣增大”
#
#
#
# “嗯，这是最后一次参加保健体育了
# 那个，不是理科吗？
#
#
# 算了吧……“
#
#
# 一脸发情，拿着保健体育教科书开始朗读的双胞胎
# 嗯，因为变态相机变了，但是内容很厉害
#
#
#
# “肚子好的男人和女人一进有床的房间就做爱
# 做爱、吃饭的时候脱下衣服是礼仪，但是根据今天的不同，穿衣服也有不要紧的情况
# ”
#
#
# 是因为发情还是因为年龄的关系，读了发音有点口齿不清的教科书的双胞胎
# 刚才给你写了理解度上升，所以应该很好地理解写的是什么
# 作为证据，至今为止笑容满面的脸虽然越来越害羞，但却津津有味地看着教科书和这边发生了变化
#
#
#
# “这个男人是个吝啬鬼？
#
#
# 然后，女人把馒头用年糕弄湿，把它弄湿
# “
#
#
# 在这里，朗读停止了
# 从教科书上一直往这边看的双胞胎
# 我给你一个微笑
#
#
#
# “有什么不明白的事情吗？”
#
#
# “嗯，嗯……这里的……模糊？
#
#
# 什么呀，什么呀？”
#
#
# 就像说了好几次一样，双胞胎的理解度上升了，大概理解了吧
# 但是，叔叔很亲切，我来给你说明一下吧
#
#
#
# “看，这里
# 小灯笼变硬了吧
# 这就是勃起
# ”
#
#
# “哇，哇♡
#
#
# 这个，这就是勃起……爸爸的小灯笼我见过，但是没有这么大啊？”
#
#
# 一下子靠近这边观察自己胯间的双胞胎
# 虽然很红，但是很感兴趣，好像没有讨厌的感觉
#
#
#
# “爸爸勃起的话也会变大吧
# 大小因人而异……想直接看叔叔的小灯笼勃起吗？”
#
#
# “嗯……嗯，嗯
# 因为我不懂作业，所以要学习
# ”
#
#
# 像是在对自己说什么一样点头的双胞胎
# 那就按照希望的那样
# 把衣服脱了
#
#
#
# “啊……啊，是吗？上面写着必须裸体
# 那么，我也要裸体……”
#
#
# 理解得快真好啊
# 但是还处于准备阶段
# 好好享受吧
#
#
#
# 因为是一个人脱的，所以让我在旁边欣赏，嗯，几乎没有性感
# 我觉得带着亲戚的孩子来守护着
#
#
#
# “哇♡
#
#
# 非常大……教科书上写着里面好的男人和女人进入有床的房间就会做爱……“
#
#
# 赤身裸体地匍匐着观察着大叔的小鸡鸡，扭蛋的孩子嘟囔着
#
#
#
# “和叔叔关系很好吧
# ”
#
#
# “嗯
# ”
#
#
# “有床，两个人都裸体了
# ”
#
#
# “嗯
# ”
#
#
# “预习很重要吧
# ”
#
#
# “啊……嗯，嗯
# 预习！
#
#
# 学习的预习，请叔叔帮忙！”
#
#
# 带着孩子般的笑容突然点头的推特罗利孩子
# 另外，因为是全裸的大叔的金棒在旁边，所以是违背道德感更强的画面
#
#
#
# “首先是从勃起的练习开始
# 用双手温柔地抓住小鸡鸡，上下移动
# ”
#
#
# “嗯……这个，这样吧
# ”
#
#
# 嗯嗯嗯嗯地拼命地握着小鸡的竿开始手心
# 比想象中还要兴奋呢
#
#
#
# “哇，刚才有什么东西冒出来了
# 奇怪的味道……但是，可能有点喜欢？”
#
#
# 哎呀，毕竟对萝莉子来说是那样的时候，所以在拍的照片上写上喜欢小鸡鸡，改变常识
#
#
#
# “很棒
# 之后可以用嘴舔或者夹在乳房里
# ”
#
#
# 被这么一说，看着自己的胸部发呆的双胞胎
# 嗯，因为妈妈有很多东西，所以乳房对将来很期待
#
#
#
# “用嘴舔就好了吧
# 嗯♡
#
#
# 喂，喂……这个，这样吗？”
#
#
# “嗯！
#
#
# 对了对了，小蓝的嘴很舒服，好像已经射精了
# “
#
#
# 非常高兴的双胞胎
# 哦，哦！？
#
#
# 不，要是那么神经质的话真的会射精的！？
#
#
# 也许是因为理解度提高了吧，有才能吗，进步速度好厉害啊！？
#
#
# “哇！？
#
#
# 小鸡鸡里有很多白色的♡
#
#
# 说是“蹲下”♡
#
#
# 可能喜欢这个白色的味道♡“
#
#
# 哦！？
#
#
# 对着射精的小灯笼嘴，不停地吸着精液，真是太色情了
#
#
#
# 舔嘴唇上的精液的表情和刚才完全相反……
#
#
# “小蓝，该休息了
# 带着点心和饮料……”
#
#
# 正好射精结束的时候，门空了，妻子进来了
#
#
#
# “啊……”
#
#
# 一瞬间凝固的空气
#
#
#
# “我以为你已经在学习了……不能再给叔叔添麻烦了吧？”
#
#
# 啊，因为常识的改变，妻子觉得在家里做爱是理所当然的
# 我一瞬间着急了
#
#
#
# “啊，学习啊！
#
#
# 保健体育的预习！”
#
#
# 就这样，我给你看了被修改的色狼保健体育教科书的性爱页面
#
#
#
# “啊，是这样吗？
#
#
# 对不起
# 我以为你一定在和叔叔玩
# “
#
#
# 没有错吧……但是，这是亲子盖饭的机会
#
#
#
# “你是个非常热心学习的好姑娘，几乎没有教过你，吓了我一跳
# ”
#
#
# “啊！？
#
#
# 这样啊，平时总是马上把作业扔出去玩，果然还是让别人看比让一个人好吗？“
#
#
# “哇，我也能做到！”
#
#
# 若无其事地拍下妻子的照片，写上“为了女儿的学习什么都可以做”
#
#
#
# “啊，对了，夫人
# 你能帮我女儿预习做爱吗？”
#
#
# “诶！？”
#
#
# 到底做爱和直球不好吧
# 不，这里推着推倒吧
#
#
#
# “果然，我觉得让妻子也一起学习的话，女儿也会更有干劲的
# 特别是让她看看有经验的妻子的做法会比较安心
# 当然，我也会配合的
# 趁现在好好掌握知识比较好
# ”
#
#
# 像流水一样，把妻子拿着的盂兰盆节放在桌子上，紧紧地挤在一起
#
#
#
# “嗯，嗯……嘛，家务基本上都做完了……那个，没关系
# ”
#
#
# 妻子的视线很低，即使觉得常识改变没有问题，果然还是会意识到男性的小鸡鸡吧
# 羞答答的人妻，真好
#
#
#
# “太好了！
#
#
# 那么，妈妈也脱了吧
# “
#
#
# “诶！？”
#
#
# 天真无邪地把手伸到自己母亲的裙子上脱下来的女儿
#
#
#
# “咦，教科书上也有做爱的时候脱，啊，不脱的时候吗？”
#
#
# “嗯，因为是基本的范本，所以还是脱下来比较好吧？”
#
#
# 一开始还是想看裸体吧
# 从衣服上也能明白的那个胸围（变态照相机更倍）应该是绝景
#
#
#
# “啊，如果是为了学习的话就没办法了……那么，再见
# ”
#
#
# 第14章
#
# 在全裸的双胞胎和全裸的大叔面前稍微有些困惑地解开围裙，脱下连衣裙的妻子
#
#
#
# 黑色的蕾丝支撑着柔软的乳房，很不错
#
#
#
# “妈妈的内衣好厉害！”
#
#
# 虽然也受到了女儿的好评，但本人似乎感到不协调，“咦，应该是那个人用的，为什么今天来了呢？”嘟哝着
# 老公看到这样也会很开心吧
# 大概是因为用变态相机拍了几次所以改变了的结果吧，这样也不错
#
#
#
# 在人前穿着内衣的害羞和只是帮助女儿学习为什么这么害羞的混乱表情非常好
# 发了一次的小灯笼已经变得精神起来了呢
#
#
#
# “那么，做到什么程度了？”
#
#
# 虽然记得，但为了在学习中进行，以向推特罗利孩子提问的形式进行
#
#
#
# “我做到了，接下来就是全部了！”
#
#
# 嗯嗯，点头靠近妻子
#
#
#
# “那嚒，让妈妈从前戏的实际表演中帮忙吧
# ”
#
#
# “哎呀！？”
#
#
# 把手放在夫人的腰上，躺在床上……哎呀，如果有点小或者坏了就不好了，请在地毯上做吧
#
#
#
# “那嚒，夫人：”拜托了
# “
#
#
# 从胸罩下举起的手沉下去！？
#
#
# 也许是准备了晚饭，微微飘香的料理味道又很好
#
#
#
# “嗯♡
#
#
# 明明是女儿在看……这样的声音是不行的，啊，啊♡
#
#
# 那里很弱“
#
#
# 被拜托帮忙学习的妻子虽然身体有点发麻，但是无法抵抗，胸部和那里被玩弄，吐出了一口气
#
#
#
# “因为是前戏的学习，所以没关系
# 你看，为了让女儿好好看，把内裤拿下来吧
# ”
#
#
# 嗖嗖地一声，脱下妻子的内裤
# 整齐的灌木丛
# 这么说来，如果用变态相机拍摄的话，这附近的体毛处理是基本的
# 偶尔，如果想以充满野性味的变态的感觉去的话，只要写在照片上就可以了，这是两个都能享受的令人高兴的功能
#
#
#
# “哇，和我这里完全不同，大人的漫画是这样的
# ”
#
#
# 和叔叔小时候一样津津有味的双胞胎
# 已经不是和妈妈一起洗澡的年纪了，所以很新鲜吧
#
#
#
# “女人做爱的准备也和小鸡一样，刺激女阴就好了
# 就是这样的感觉
# ”
#
#
# “啊♡……啊，啊♡……嗯，嗯♡”
#
#
# 轻轻地捏起酥脆，从入口用手指拨开肉
# 嗯，反应很好
#
#
#
# “乳房特别是乳头、脖颈等也是能得到良好反应的要点
# ”
#
#
# 用剩下的一只手捏着乳头，舔着脖子全力地去做
#
#
#
# “啊，啊，啊♡
#
#
# 那里是！？……嗯♡
#
#
# 不行♡……啊♡
#
#
# 嗯♡！！！“
#
#
# “妈妈，声音太大了……心情好吗？……嗯♡
#
#
# 这样的感觉……啊♡
#
#
# 闪闪发光♡“
#
#
# 父母和孩子好像关系很好
# 两个干净的飞沫弄湿了地毯
# 拍张漂亮的脸吧
#
#
#
# “哇，你在发牢骚……这不是在泄漏吗？”
#
#
# “是啊，女人心情变好的话，会为了让她放进金棒而拿出汤来
# ”
#
#
# 为了让双胞胎孩子容易看，把妻子的大腿抬起来
#
#
#
# “啊，啊♡……刚才的头发打中了♡
#
#
# 明明是在女儿面前……但是，这是为了女儿的学习……啊♡“
#
#
# 好像做得很好
# 在客厅拍的照片上写上“背德感很快感”是不是很有效呢
#
#
#
# “那就让你妈妈来表演性爱吧
# 你看，好好学习
# ”
#
#
# “嗯！
#
#
# 啊，叔叔的小鸡……哇♡
#
#
# 真的被妈妈的漫画吞没了♡
#
#
# 这就是性爱……好厉害♡“
#
#
# 不愧是一个孩子的母亲
# 极粗的金棒也吞下了，里面的肉饼也是高级霜降肉的感觉，这是值得期待的
#
#
#
# “嗯♡
#
#
# 在女儿看到之前……嗯，嗯♡……竟然接受丈夫以外的金棒♡
#
#
# 明明不行，这是为了学习……嗯♡
#
#
# 为什么这么舒服！？”
#
#
# “可以吗？
#
#
# 你有那么舒服吗？”
#
#
# 因为第一次看到妈妈的痴态而兴奋的双胞胎
# 那么，为了学习，让我给你看加奇叔叔和妈妈的加奇塞克斯
#
#
#
# “那么，我开动了，夫人
# ”
#
#
# “啊♡
#
#
# 现在……嗯♡
#
#
# 嗯！？……感觉太多了♡……不行！？
#
#
# 到小鸡鸡里面♡
#
#
# 哇哦♡♡！！！“
#
#
# 从一开始就是全节气门的妻子
# 这个不能输哦
# 把腰紧紧地缠在一起
#
#
#
# “哈哈♡
#
#
# 哈哈♡
#
#
# 哈哈♡……这是第一次♡……嗯♡“
#
#
# “哇♡
#
#
# 妈妈和叔叔相连的地方……嗯♡
#
#
# 看起来很舒服♡……明明比我所有的手指都大……只有妈妈很狡猾♡“
#
#
# 嗯，多么热心学习的双胞胎啊
#
#
#
# “那嚒，虽然有点早，但还是要学习3p
# 这是大家友好做爱的礼仪，现在可以舔叔叔在妈妈里面放小鸡的地方，揉乳房，做各种各样的事情
# ”
#
#
# “啊，好！”
#
#
# 微笑着靠近母亲肉体的女儿
# 为了容易舔，把身体抬起来
#
#
#
# “诶，诶！？
#
#
# 嗯♡……那样啊，啊，啊，啊♡……那里很敏感♡！！！“
#
#
# 毫不犹豫地把眼前妈妈的豆子一饮而尽的双胞胎
# 刚才叔叔给我示范了一下，妈妈的弱点我大概知道了，已经是专业的手势了
#
#
#
# “喂♡
#
#
# 叔叔的金棒♡
#
#
# 但是，叔叔拜托你了，没关系
# 让妈妈心情舒畅♡“
#
#
# “啊♡！？
#
#
# 变得奇怪♡……啊，啊♡……啊♡！？
#
#
# 那样的地方♡……好可爱♡！？“
#
#
# 这也提高了不输和活塞的速度，两个人责备妻子
# 即使妻子嘴上否定了，身体也很诚实，勒紧小鸡的力量越来越强，我很高兴
#
#
#
# “那么，最后给你看中出的样品吧？”
#
#
# “哈，哈♡……诶，中出……！？”……！？
#
#
# 嗯♡
#
#
# 但是，那是……虽说是为了学习……啊♡
#
#
# 里面！？
#
#
# 熊啊！？”
#
#
# “嗯哼！？
#
#
# 小鸡鸡吓了一跳♡
#
#
# 我知道这个♡
#
#
# 射精！
#
#
# 在妈妈心中做了很多事♡
#
#
# 为了让心情变好，我也会努力的♡
#
#
# 哈哈♡“
#
#
# 因为女儿对陰核的甜味咬到第二次绝顶的妻子
# 与此同时，将大量的精子中出
#
#
#
# “嗯♡
#
#
# 出来了！？……啊，啊♡
#
#
# 啊♡！？“
#
#
# 用飞沫溅到女儿身上的妻子
# 地毯上已经有各种各样的体液了
#
#
#
# 第15章
#
# “下一个是我！
#
#
# 叔叔，快点快点♡“
#
#
# 虽然妈妈在中出的时候倒下了，但是扭蛋的孩子很有精神地露出屁股，看起来还很有精神
# 把肚脐上的叔叔的小鸡鸡放进去的话好像会坏的，但是没关系
# 而且事先用变态照相机写了什么样的小鸡鸡都可以接受，所以已经做好了对策
#
#
#
# “你是个热心学习的姑娘，真让人羡慕
# ”
#
#
# “啊……啊♡……是的，我引以为豪的……啊♡
#
#
# 因为是女儿……“
#
#
# 妻子抱着把女阴放在一边，视线紧紧盯着小矮人的女儿高兴地笑着
# 虽然太可爱了判断力相当差，但是为了女儿的学习而挺起身体变成肉被……嗯，色情的亲子盖饭的景色是最棒的
#
#
#
# “哈，哈……叔叔，叔叔♡
#
#
# 叔叔的金棒♡
#
#
# 塞进青眼的口水拖泥带水的孩子漫画里♡
#
#
# 在妈妈面前像妈妈一样犯下错误♡“
#
#
# 已经到了忍耐极限的双胞胎
# 因为好好地说出了告诉你的愿望，所以按照你希望的那样，嗯！？
#
#
# 孩子阿小穴的勒紧厉害！？
#
#
# 用变态照相机改造了的肉的墙勒紧全体，不过到里面全部咽下！？
#
#
# “哇哦♡
#
#
# 啊，啊啊♡……里面有♡
#
#
# 我知道你被塞进了蓝色中♡
#
#
# 嗯”♡……好厉害♡
#
#
# 里面好像全部都出来了♡……呵呵，哇，哇哦♡……身体里全部都很舒服♡♡！！！“
#
#
# “啊，啊♡
#
#
# 爸爸让我放那么多，明明已经变得很普通了，感觉很舒服的声音♡“
#
#
# 破瓜的疼痛也因为快感全部被吹跑了，已经完全融化了的脸和妻子一样发出娇声的双胞胎
# 这样就可以加入大人的行列了呢
#
#
#
# 把夫人的阴道缩小1/2左右，弹性和硬度变成了2倍左右的感觉，感觉是新的
# 一般情况下应该只放一半左右，但是多亏了变态相机，连根都能吃到，就像是极上的新奥纳大厅一样的使用感
#
#
#
# “啊，啊♡
#
#
# 啊♡
#
#
# 小鸡鸡♡……哈哈♡
#
#
# 嗯♡……好厉害♡
#
#
# 竟然这么舒服♡
#
#
# 更多，更多♡……告诉我吧♡“
#
#
# “啊，啊♡……小蓝竟然露出这样的表情♡
#
#
# 我好像也一起被侵犯了♡……只是看着女儿的学习，我什么都没做♡“
#
#
# 母女俩好像都很开心，配合活塞让我听到很好的声音
#
#
#
# “啊♡
#
#
# 嗯♡
#
#
# 这个样子♡
#
#
# 小鸡，最里面了♡
#
#
# 啊♡
#
#
# 啊，啊，啊♡“
#
#
# “嗯♡
#
#
# 小蓝！？
#
#
# 不要把乳房弄得乱七八糟！？
#
#
# 啊，那里磨破了♡
#
#
# 被女儿欺负了♡！！！“
#
#
# 当然，也不要忘记拍哈梅，拍得啪啪啪啪的
# 因为是女儿的第一次纪念，所以以后请作为相册保存吧
#
#
#
# 嗯，虽然是用色狼优等生、魔性癖、魔性肉体、维奇家族等魔术笔写的，但是除了写的本人以外好像看不到，所以没关系吧
#
#
#
# “从金棒开始就变得乱七八糟，脑子一片空白♡
#
#
# 欢迎♡
#
#
# 好厉害♡♡“
#
#
# “嗯♡……用女儿的娇声♡……我也会来的♡
#
#
# 小蓝♡
#
#
# 小蓝♡“
#
#
# 呵呵，这是两个人一起吃的时候的亲子盖饭
# 里面和外面都有很多汁，给你做完吧
#
#
#
# “嗯，满分
# 那我就射精了！”！
#
#
# 这样预习就很顺利了吧！”
#
#
# “啊啊♡
#
#
# 来了♡
#
#
# 叔叔的寿司♡
#
#
# 阿珠子扑通扑通♡
#
#
# 一元♡
#
#
# 最舒服的来了哦♡！！！“
#
#
# “啊♡
#
#
# 啊♡……传达了隔着女儿的肚子射精的消息♡
#
#
# 和女儿一起去吧♡！！！“
#
#
# 抓住双胞胎的屁股，从狠狠地戳到里面的小鸡鸡中拿出大量的精液
# 无论什么时候拿出来都射精在阴道上是很好的
# 从接合部分像喷泉一样漏出精子，孩子的房间已经只闻到精子的味道了，不过那里还是先放着吧
#
#
#
# “嗯……哇♡……啊，啊♡……学习性爱吧♡”
#
#
# 为了纪念还在肚子里溢出精子的双胞胎
#
#
#
# 那里有亲子关系很好地笑着的家庭照片
# 嗯，是赤脚倒在床上的父亲吗？
#
#
# 笑着两个人握着小鸡的妻子和女儿
# 今后，为了能继续美满的家庭，对像父亲一样的人要写上精力无限

# %%
def 清理(n):
        path = 'C:\\Users\\user\\Desktop\\JYPUTER_試做\\' + org_name
        if not os.path.isdir(path):
            os.makedirs(path)
        n = "%03d"%n

        name = path+"\\"+org_name + '__'+str(n)+'.txt'

    #    f = open(name, 'w', newline='\n', encoding="utf-8")
        print('第'+str(n)+'章\n')
        # 用a而不是用 w 是因為要 for 寫入
        f = open(name, 'w',  newline='\n', encoding="utf-8")
        f.write('')
        f.close()

# %%
# count=0

# for ii in range(len(中文翻譯_list)):
# #        print(ii)
#         清理(ii)
#         count+=1

# %%
# couny=0
# for i in 中文翻譯_list:
# #     if (count==5):
# #         break
#     for j in i :
#         kkk=j.text.split('。')
#         #print(kkk)
#         print(type(kkk))
# #     count+=1

# %%
# for j in 中文翻譯_list[3]:
#     print(j.text)
#     print("-------------------------")

# %%
# def ck(count):
#     count="%03d"%count
#     print(count)

# %%
# for i in range(10):
#     ck(i)

# %%
# 中文翻譯_list_取代=[]
# 中文翻譯_list_取代_tmp=[]
# for i in 中文翻譯_list:
#     for j in i:
#         kkk=j.text.split('。')
#         kkk=kkk.replace("愚息",'金棒')
#         kkk=kkk.replace("猎奇",'cheat')
#         kkk=kkk.replace("腮红",'cheat')
#         kkk=kkk.replace("芒果",'小穴')
#         kkk=kkk.replace("曼科",'小穴')
#         kkk=kkk.replace("愚蠢的气息",'金棒')
#         kkk=kkk.replace("龙猫",'黏呼呼')
#         kkk=kkk.replace("滑板",'史萊姆')
#         kkk=kkk.replace("克里特里斯",'陰核')
#         kkk=kkk.replace("蒲公英",'金棒')
#         kkk=kkk.replace("面包",'砰砰')
#         kkk=kkkreplace("好球",'伊庫')
#         kkk=kkk.replace("波尔奇奥",'子宫颈')
#         kkk=kkk.replace("poruchio ",'子宫颈')
#         kkk=kkk.replace("阿索科",'金棒')
