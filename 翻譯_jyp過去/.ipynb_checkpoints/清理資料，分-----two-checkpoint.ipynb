# %%
from selenium import webdriver

# %%
import re

# %%
import requests as rq
from bs4 import BeautifulSoup
import io
import time

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
tmp_japan_list=[]
import csv
with open('R18幼馴染を盗撮してたらポイントカード制が始まった.csv',newline='',encoding="utf-8") as csvfile:
  # 讀取 CSV 檔內容，將每一列轉成一個 dictionary
  rows = csv.reader(csvfile)

  # 以迴圈輸出指定欄位
  for row  in rows:
    tmp_japan_list.append(''.join(row))

# %% [markdown]
# tmp_japan_list[5]

# %%
japan_list=[]
for str1 in tmp_japan_list:
    tmp = re.sub(u"\s+|\\r|\\n|\\u3000|├|┼||┘|┴|┌|┬|└|─|│|┤|┐|●|◇|◆",'',str1)
    japan_list.append(list(tmp))

# %%
tmp_japan_list=[]

# %%
japan_list[5]
# Out:
# ['家',
#  'に',
#  '帰',
#  'っ',
#  'て',
#  'ま',
#  'ず',
#  'お',
#  'こ',
#  'な',
#  'っ',
#  'た',
#  'の',
#  'は',
#  '、',
#  'ハ',
#  'ン',
#  'カ',
#  'チ',
#  'に',
#  '挟',
#  'ん',
#  'で',
#  'い',
#  'た',
#  '優',
#  '菜',
#  '（',
#  'ゆ',
#  'う',
#  'な',
#  '）',
#  'の',
#  '陰',
#  '毛',
#  'の',
#  'フ',
#  'ァ',
#  'イ',
#  'リ',
#  'ン',
#  'グ',
#  'だ',
#  '。',
#  '一',
#  '辺',
#  'が',
#  '四',
#  'セ',
#  'ン',
#  'チ',
#  '程',
#  '度',
#  'の',
#  '長',
#  'さ',
#  'の',
#  'ウ',
#  'ル',
#  'ト',
#  'ラ',
#  'ジ',
#  'ッ',
#  'パ',
#  'ー',
#  '付',
#  'き',
#  'の',
#  '小',
#  'さ',
#  'な',
#  '袋',
#  'に',
#  '陰',
#  '毛',
#  'を',
#  '入',
#  'れ',
#  'る',
#  '。',
#  'そ',
#  'し',
#  'て',
#  'ま',
#  'だ',
#  '使',
#  'っ',
#  'て',
#  'い',
#  'な',
#  'い',
#  'ノ',
#  'ー',
#  'ト',
#  'を',
#  '取',
#  'り',
#  '出',
#  'し',
#  'て',
#  '、',
#  '最',
#  '初',
#  'の',
#  'ペ',
#  'ー',
#  'ジ',
#  'に',
#  '張',
#  'り',
#  '付',
#  'け',
#  'た',
#  '。',
#  'そ',
#  'の',
#  'ペ',
#  'ー',
#  'ジ',
#  'に',
#  '今',
#  '日',
#  'の',
#  '日',
#  '付',
# ...

# %%
a=reshape(japan_list[5],1000)

# %%
ttmmp=[]
for i in a:
 #   print(''.join(i)) 
    ttmmp.append(''.join(i))

# %%
ttmmp[0]
# Out:
# '家に帰ってまずおこなったのは、ハンカチに挟んでいた優菜（ゆうな）の陰毛のファイリングだ。一辺が四センチ程度の長さのウルトラジッパー付きの小さな袋に陰毛を入れる。そしてまだ使っていないノートを取り出して、最初のページに張り付けた。そのページに今日の日付と『水道橋優菜』としっかり記して挟んでおく。その作業が終わってから、優菜からもらったヒョウ柄と黒のツートン調のパンツでシコシコしてやろうと思い、ポケットから取り出した。ピロン♪不意にスマホに通知が届いた。伸介（しんすけ）からの連絡のようにどうでもいいものだったら無視していたが、通知を送ってきた相手は『ゲッター11』だ。スマホのロックを解除してアプリを起動してみる。新着メッセージいつも『ゲッター11』をご利用いただき、誠にありがとうございます。新機能が加わりました。・女性コレクション機能→被写体の名前ごとにデータを振り分け、ファイリングする機能です。今後、盗撮した画像や動画は当アプリのこの機能により管理されます。・ポイントカード配布→被写体の名前ごとにポイントカードを作成し、当アプリで管理いたします。なお、画像動画を問わず、１盗撮ごとに１ｐｔの付与になります。また、以前盗撮したことのある下着を盗撮した場合、ポイントは加算されませんのでご注意ください。引き続き『ゲッター11』をお楽しみください。明日以降いろいろとこの謎の盗撮アプリについて検証していくつもりだったが、向こうがその手間を省いてくれた。とりあえずポイントがどうやって加算されるのかは確定された。気になるのはポイントを貯めていけばどんな特典が待っているのかだ。俺はさっそくメッセージを閉じてアプリを先へ進めた。いつもはすぐカメラ撮影画面になるのに、今回はメニューが表示された。・カメラモード・動画モード・女性コレクションこの三つがタップできる。ためしに女性コレクションをタップしてみると、画面はスマホの連絡先機能のような画面に移り、その一番上に『水道橋優菜』の文字が浮かんでいた。それをさらにタップすると、デジタルのカードが一面に表示される。どうやらこれがポイントカードのようだ。表紙には『水道橋優菜』と文字が刻まれており、その横に優菜の現在の顔写真がはられている。こんな写真、どこで仕入れてきたんだか。さらにこんな情報まで乗っていた。Ｔ１６０．５ｃｍＢ？？？Ｗ５５Ｈ８３『
# ...

# %%
ttmmp[1]
# Out:
# '身長か。他はスリーサイズで間違いないだろう。『Ｂ』の部分が『？？？』になっているのが気になったが、まあいい。しかし優菜のやつ、ウエストが５５センチしかないのか。細すぎるだろう。表紙はさらに下へスクロールできるようになっている。その先へと進んで見ると、ようやくポイントカードらしき情報が見えてきた。パンチラ盗撮ポイント合計３ｐｔ３ｐｔ水道橋優菜から脱ぎたてパンツを一枚もらえる５ｐｔ？？？７ｐｔ？？？１０ｐｔ？？？１５ｐｔ？？？ポイント最大値は１５ｐｔのようだ。こうして見てみると、どのタイミングで特典付与されるのかはわかるけれど、どんな特典が付与されるのかは謎に包まれたままだ。しかし３ｐｔの時点でパンツをもらえるというぶっ壊れ具合の特典だ。１５ｐｔまで貯めればもしかすると……。「焦ってはいけないな。まずは５ｐｔ。そこからだ」とりあえず俺は優菜を盗撮し続ければいいのだ。バレるかもしれないというリスクはつきまとうが、それを乗り越えた先に美味しい特典が待っている。「ポイントカードまわりのことは大体わかったとして、だ。女性コレクション機能か」単純に考えると盗撮した対象をアプリ内でファイリングすることを意味する。さっきも見たように、これからいろんな女の子をどんどん盗撮していけば、連絡先みたいにズラッと並んでいくのだろうか？その機能についてもちょっと試してみたいな。ちょうどそう思っていた時だった。「ねえお兄。学校で数学の宿題が出て、わけわかんないから教えて？」俺の部屋に妹が入ってきた。名前は多治見（たじみ）愛華（あいか）。中学三年生だ。今日もトレードマークのポニーテールを結っている。幼い顔立ちながらしっかりと顔は整っているので、同級生の男から何回か告白されたりしているらしいが、付き合うまでにはいたっていないとのこと。家にいる時はいつもラフな恰好をしていて、今も裾まわりがゆったりとしているショートパンツとＴシャツ姿だった。ちょうどいい獲物がきた。俺は心の中でほくそ笑んだ。結果は『女性コレクション』は俺の想像通りの機能だった。俺の教えを真面目に聞いている愛華には悪いと思ったけれど、ゆったりと広がっているショートパンツの裾の隙間にレンズの目をあてて逆さ撮りさせてもらった。愛華が自分の部屋に戻った後でアプリを起動して『女性コレクション』を確認する。【多治見愛華】Ｔ１４８．２ｃｍＢ？？？
# ...

# %%
def reshape(lst, n):
    return [lst[i*n:(i+1)*n] for i in range(len(lst)//n)]

# %%
cut_novel=[]
for str1 in japan_list:
    a=[]
    a=reshape(str1,1000)
    for i in a:
 #   print(''.join(i)) 
        cut_novel.append(''.join(i))

# %%
cut_novel[5]
# Out:
# 'この日の優菜（ゆうな）のパンツは白だった。男子トイレの個室でそれを確認し、俺はほくそ笑んだ。右手に持つスマホの画面に表示されているひとつの動画。それは机の下で足をバタバタと行儀悪くばたつかせていた、優菜の下半身を写しているものだった。俺はまず自分の制服スラックスの右ポケットに穴をあけた。右ポケットにスマホを突っ込むと、ちょうどレンズが穴に重なるような位置だ。あとは『ゲッター11』を起動してタイミングを見計らって動画モードの撮影ボタンを押し、適当に優菜を煽って苛立たせるだけの仕事だった。昔から優菜は怒ると地団太を踏む癖がある。そうしてスカートをはためかせ、パンチラを狙うというのが俺の作戦だった。「我ながら見事な作戦だ」地団太を踏んで、スカートがはためく瞬間に白い逆三角形がチラついている。さすがに机の下の映像でやや暗く、パンツの生地までは判断できなかったが、フロント部分のレースの飾りまでしっかり見える瞬間もあって良い。柔らかそうな白い太股（ふともも）も輝いており、足をバタつかせるたびにプルンプルン揺れる股肉が大変にそそる。細身だがしっかり肉もついていて女性的な柔らかさを醸（かも）し出しているこの太股を、彼氏である敦（あつし）は良いように扱っているのかと思うと嫉妬で気が狂いそうだ。欲を言えばもっと大胆にパンチラしてほしかったが、初回の試みとしてはまずまずだろう。焦る必要はない。急いては事を仕損じるという言葉もあるくらいだ。ゆっくり精度を上げていけばいい。それに今回、まったく喋ったことのなかった敦とコンタクトできたというのも大きな成果だ。俺が優菜のパンチラを盗撮しようと思ったら、嫌でも優菜に近づく必要がある。すでに疎遠になってしまっていた優菜ともう一度仲良くするよりも、彼氏であり比較的優菜と一緒にいることが多い敦と仲良くした方が合理的だ。あわよくば優菜としゃべる機会も増える。「ククク。計画通りだ」今まで自分のことを頭良いと思ったことはなかったし、他人と比べようと思うこともなかったからどうでもよかったが、この認識を改めざるをえない。「この俺は天才だっ！」優菜のパンチラ動画を何度もリピート再生してシコシコしながら、俺はそう呟いた。この日はこの動画で三回射精した。翌週の月曜日。この日も朝から優菜のパンチラを盗撮することで頭が一杯だった。さすがにまたアイツのクラスを訪ねるのは
# ...

# %%
with open('R18幼馴染を盗撮してたらポイントカード制が始まった.csv', 'w', newline='',encoding="utf-8") as csvFile:

    writer = csv.writer(csvFile)
    for a in cut_novel:
        writer.writerow(a.split(','))

# %%
# def wait(locator, timeout=10):
#     #'''等到元素加载完成'''
#     WebDriverWait(driver, timeout).until(EC.presence_of_element_located(locator))

# %%
# def get_javascript0_links(url, class_name, sleep_second=0.01):
#     """
#     Selenium模拟用户点击爬取url
#     :param url: 目标页面
#     :param class_name: 模拟点击的类
#     :param sleep_second: 留给页面后退的时间
#     :return: list, 点击class为class_name进去的超链接
#     """

#     def wait(locator, timeout=10):
#         """等到元素加载完成"""
#         WebDriverWait(driver, timeout).until(EC.presence_of_element_located(locator))

#     options = Options()
#     options.add_argument("--headless")  # 无界面
#     driver = webdriver.Chrome(chrome_options=options)
#     driver.get(url)

#     locator = (By.CLASS_NAME, class_name)
#     wait(locator)
#     elements = driver.find_elements_by_class_name(class_name)
#     link = []
#     linkNum = len(elements)
#     for i in range(linkNum):
#         wait(locator)
#         elements = driver.find_elements_by_class_name(class_name)
#         driver.execute_script("arguments[0].click();", elements[i])
#         time.sleep(sleep_second)
#         link.append(driver.current_url)
#         time.sleep(sleep_second)
#         driver.back()
#     driver.quit()
#     return link

# %%
# trans_list=[]
# driver = webdriver.Chrome()
# driver.get("https://fanyi.baidu.com/#jp/zh/") #前往這個網址
# time.sleep(2)
# search_input = driver.find_element_by_id('baidu_translate_input')
# search_input.send_keys(cut_novel[5])
# time.sleep(5)
# driver.get("https://fanyi.baidu.com/#jp/zh/")
# soup = BeautifulSoup(driver.page_source, 'html.parser')
# tmp=soup.find('p','span')
# tmp=str(tmp)
# trans_list.append(tmp)
# time.sleep(5)
# #driver.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-32a4ce4e9dc6> in <module>
#       5 search_input = driver.find_element_by_id('baidu_translate_input')
#       6 search_input.send_keys(cut_novel[5])
# ----> 7 link = get_javascript0_links('https://fanyi.baidu.com/#jp/zh/', 'trans-btn')
#       8 link.click()
#       9 time.sleep(5)
#
# <ipython-input-127-b69c0ef03b69> in get_javascript0_links(url, class_name, sleep_second)
#      12         WebDriverWait(driver, timeout).until(EC.presence_of_element_located(locator))
#      13
# ---> 14     options = Options()
#      15     options.add_argument("--headless")  # 无界面
#      16     driver = webdriver.Chrome(chrome_options=options)
#
# NameError: name 'Options' is not defined

# %%
trans_list
# Out:
# ['None']

# %%
# trans_list=[]
# driver = webdriver.Chrome()
# driver.get("https://fanyi.baidu.com/#jp/zh/") #前往這個網址
# time.sleep(2)
# for i in cut_novel:
#     search_input = driver.find_element_by_id('baidu_translate_input')
#     search_input.send_keys(i)
#     driver.find_element_by_id('translate-button')
#     time.sleep(2)
#     soup = BeautifulSoup(driver.page_source, 'html.parser')
#     tmp=soup.find('p',class_="ordinary-output target-output").text
#     tmp=''.join(tmp)
#     trans_list.append(tmp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-c4c10da52ab4> in <module>
#       9     time.sleep(2)
#      10     soup = BeautifulSoup(driver.page_source, 'html.parser')
# ---> 11     tmp=soup.find('p',class_="ordinary-output target-output").text
#      12     tmp=''.join(tmp)
#      13     trans_list.append(tmp)
#
# AttributeError: 'NoneType' object has no attribute 'text'
